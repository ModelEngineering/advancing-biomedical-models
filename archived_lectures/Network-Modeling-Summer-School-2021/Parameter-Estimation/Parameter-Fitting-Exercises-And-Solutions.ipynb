# %% [markdown]
# # PARAMETER FITTING EXERCISES AND SOLUTIONS

# %% [markdown]
# # Preliminaries

# %% [markdown]
# ## Installs

# %%
IS_COLAB = True

# %%
if IS_COLAB:
    # !pip install -q SBStoat
    # !pip install -q tellurium
    pass

# %% [markdown]
# ## Imports

# %%
# Python packages used in this chapter
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import os
import pandas as pd
import urllib.request # use this library to download file from GitHub
from SBstoat.namedTimeseries import NamedTimeseries, TIME
from SBstoat.modelFitter import ModelFitter
import SBstoat
import tellurium as te

# %% [markdown]
# ## Helper Functions
# The helper functions reside in the course github repositor in the ``src`` folder. The codes below import these modules into the notebook.

# %%
def getSharedCodes(moduleName):
  """
  Obtains common codes from the github repository.

  Parameters
  ----------
  moduleName: str
      name of the python module in the src directory
  """
  if IS_COLAB:
      url = "https://github.com/sys-bio/network-modeling-summer-school-2021/raw/main/src/%s.py" % moduleName
      local_python = "python.py"
      _, _ = urllib.request.urlretrieve(url=url, filename=local_python)
  else:
      local_python = "../../src/%s.py" % moduleName
  with open(local_python, "r") as fd:
    codeStr = "".join(fd.readlines())
  print(codeStr)
  exec(codeStr, globals())

# Acquire codes
getSharedCodes("util")

# TESTS
assert(isinstance(LINEAR_PATHWAY_DF, pd.DataFrame))
# Out:
# import pandas as pd
# import urllib.request
#
# # Linear pathway data
# BASE_URL = "https://github.com/sys-bio/network-modeling-summer-school-2021/raw/main/"
# BASE_DATA_URL = "%sdata/" % BASE_URL
# BASE_MODULE_URL = "%ssrc/" % BASE_URL
# BASE_MODEL_URL = "%smodels/" % BASE_URL
# LOCAL_FILE = "local_file.txt"
#
#
# def getData(csvFilename):
#     """
#     Creates a dataframe from a CSV structured URL file.
#
#     Parameters
#     ----------
#     csvFilename: str
#         Name of the CSV file (w/o ".csv" extension)
#
#     Returns
#     -------
#     pd.DataFrame
#     """
#     url = "%s%s.csv" % (BASE_DATA_URL, csvFilename)
#     filename, _ = urllib.request.urlretrieve(url, filename=LOCAL_FILE)
#     return pd.read_csv(LOCAL_FILE)
#
# def getModule(moduleName):
#     """
#     Obtains common codes from the github repository.
#
#     Parameters
#     ----------
#     moduleName: str
#         name of the python module in the src directory
#     """
#     url = "%s%s.py" % (BASE_MODULE_URL, moduleName)
#     _, _ = urllib.request.urlretrieve(url, filename=LOCAL_FILE)
#     with open(LOCAL_FILE, "r") as fd:
#         codeStr = "".join(fd.readlines())
#     return codeStr
#
# def getModel(modelName):
#     """
#     Creates returns the string for the antimony model.
#
#     Parameters
#     ----------
#     modelName: str
#         Name of the model w/o ".ant"
#
#     Returns
#     -------
#     str
#     """
#     url = "%s%s.ant" % (BASE_MODEL_URL, modelName)
#     filename, _ = urllib.request.urlretrieve(url, filename=LOCAL_FILE)
#     with open(LOCAL_FILE, "r") as fd:
#         result = "".join(fd.readlines())
#     return result
#
# # Set models
# WOLF_MODEL = getModel("wolf")
# WOLF_DF = getData("wolf")
# WOLF_ARR = WOLF_DF.to_numpy()
# LINEAR_PATHWAY_DF = getData("linear_pathway")
# LINEAR_PATHWAY_ARR = LINEAR_PATHWAY_DF.to_numpy()
# LINEAR_PATHWAY_MODEL = getModel("linear_pathway")

# %%
LINEAR_PATHWAY_ARR = LINEAR_PATHWAY_DF.to_numpy()

# %%
print(WOLF_MODEL)
# Out:
# // Created by libAntimony v2.12.0.3
# model *Jana_WolfGlycolysis()
#
#   // Compartments and Species:
#   compartment compartment_;
#   species Glucose in compartment_, fructose_1_6_bisphosphate in compartment_;
#   species glyceraldehyde_3_phosphate in compartment_, glycerate_3_phosphate in compartment_;
#   species pyruvate in compartment_, Acetyladehyde in compartment_, External_acetaldehyde in compartment_;
#   species ATP in compartment_, ADP in compartment_, NAD in compartment_, NADH in compartment_;
#   species $External_glucose in compartment_, $ethanol in compartment_, $Glycerol in compartment_;
#   species $Sink in compartment_;
#
#   // Reactions:
#   J0: $External_glucose => Glucose; J0_inputFlux;
#   J1: Glucose + 2 ATP => fructose_1_6_bisphosphate + 2 ADP; J1_k1*Glucose*ATP*(1/(1 + (ATP/J1_Ki)^J1_n));
#   J2: fructose_1_6_bisphosphate => glyceraldehyde_3_phosphate + glyceraldehyde_3_phosphate; J2_k*fructose_1_6_bisphosphate;
#   J3: glyceraldehyde_3_phosphate + NADH => NAD + $Glycerol; J3_k*glyceraldehyde_3_phosphate*NADH;
#   J4: glyceraldehyde_3_phosphate + ADP + NAD => ATP + glycerate_3_phosphate + NADH; (J4_kg*J4_kp*glyceraldehyde_3_phosphate*NAD*ADP - J4_ka*J4_kk*glycerate_3_phosphate*ATP*NADH)/(J4_ka*NADH + J4_kp*ADP);
#   J5: glycerate_3_phosphate + ADP => ATP + pyruvate; J5_k*glycerate_3_phosphate*ADP;
#   J6: pyruvate => Acetyladehyde; J6_k*pyruvate;
#   J7: Acetyladehyde + NADH => NAD + $ethanol; J7_k*Acetyladehyde*NADH;
#   J8: Acetyladehyde => External_acetaldehyde; J8_k1*Acetyladehyde - J8_k2*External_acetaldehyde;
#   J9: ATP => ADP; J9_k*ATP;
#   J10: External_acetaldehyde => $Sink; J10_k*External_acetaldehyde;
#
#   // Species initializations:
#   Glucose = 0;
#   fructose_1_6_bisphosphate = 0;
#   glyceraldehyde_3_phosphate = 0;
#   glycerate_3_phosphate = 0;
#   pyruvate = 0;
#   Acetyladehyde = 0;
#   External_acetaldehyde = 0;
#   ATP = 3;
#   ADP = 1;
#   NAD = 0.5;
#   NADH = 0.5;
#   External_glucose = 0;
#   ethanol = 0;
#   Glycerol = 0;
#   Sink = 0;
#
#   // Compartment initializations:
#   compartment_ = 1;
#
#   // Variable initializations:
#   J0_inputFlux = 50;
#   J1_k1 = 550;
#   J1_Ki = 1;
#   J1_n = 4;
#   J2_k = 9.8;
#   J3_k = 85.7;
#   J4_kg = 323.8;
#   J4_kp = 76411.1;
#   J4_ka = 57823.1;
#   J4_kk = 23.7;
#   J5_k = 80;
#   J6_k = 9.7;
#   J7_k = 2000;
#   J8_k1 = 375;
#   J8_k2 = 375;
#   J9_k = 28;
#   J10_k = 80;
#
#   // Other declarations:
#   const compartment_, J0_inputFlux, J1_k1, J1_Ki, J1_n, J2_k, J3_k;
#   const J4_kg, J4_kp, J4_ka, J4_kk, J5_k, J6_k, J7_k, J8_k1, J8_k2;
#   const J9_k, J10_k;
# end

# %% [markdown]
# ## Linear Pathway Model

# %%
print(LINEAR_PATHWAY_MODEL)
# Out:
# R1:  S1 -> S2; k1*S1
# R2: S2 -> S3; k2*S2
# R3: S3 -> S4; k3*S3
# R4: S4 -> S5; k4*S4
#
# S1 = 10
#
# // Parameters
# k1 = 0; # Nominal value of parameter
# k2 = 0; # Nominal value of parameter
# k3 = 0; # Nominal value of parameter
# k4 = 0; # Nominal value of parameter

# %% [markdown]
# # Exercise 1: Fitting Basics

# %% [markdown]
# For the ``LINEAR_PATHWWAY_MODEL`` model and ``LINEAR_PATHWAY_DF`` data:
#
# 1. Plot the residuals for all chemical species using a model with the true values of parameters. Use the values 1, 2, 3, 4 or ``k1``, ``k2``, ``k3``, ``k4``.
# Where are the residuals the largest? Why?
#
# 1. Evaluate possible fits for ``k1``. You can quantify the "goodness" of a fit by calculating **RSQ**, the sum of squared residuals, for a set of parameter values.  Run simulations with ``k1`` in the range $[0, 4]$ for 20 equally separated values. Plot RSQ. Where on the plot does the true value appear?
#
# 1. Use the approach in (2) to propose an algorithm for parameter estimation. (No code is required; just a description in words.) What is the performance of this algorithm as the number of parameters increases?

# %% [markdown]
# ## (1) Plot the residuals

# %%
# True values of the parameters
PARAMETER_DCT = {"k1": 1, "k2": 2, "k3": 3, "k4":4}
# Create the Roadrunner object
rr = te.loada(LINEAR_PATHWAY_MODEL)
# Assign values to the kinetic constants
for name in PARAMETER_DCT.keys():
    rr[name] = PARAMETER_DCT[name]
# Run the simulation
modelArr = rr.simulate(1, 10, 100)
# Look at the result to ensure it makes sense
modelArr[0:10, :]
# Out:
#  [[       1,      10,        0,         0,          0,          0],
#   [ 1.09091, 9.13101, 0.793478, 0.0689527, 0.00599194, 0.00057025],
#   [ 1.18182, 8.33753,  1.38609,  0.230433,  0.0383089, 0.00763865],
#   [ 1.27273,   7.613,  1.81722,   0.43377,   0.103541,  0.0324644],
#   [ 1.36364, 6.95144,  2.11919,  0.646048,   0.196951,  0.0863733],
#   [ 1.45455, 6.34736,  2.31846,   0.84685,   0.309323,   0.178002],
#   [ 1.54545, 5.79578,  2.43667,   1.02443,   0.430692,   0.312421],
#   [ 1.63636, 5.29213,  2.49147,   1.17295,   0.552208,   0.491243],
#   [ 1.72727, 4.83225,  2.49719,   1.29048,   0.666889,   0.713191],
#   [ 1.81818, 4.41233,  2.46546,   1.37762,   0.769768,   0.974815]]

# %%
# Look at the observed data
LINEAR_PATHWAY_ARR[0:10, :]
# Out:
# array([[1.00000000e+00, 8.51678036e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [1.09090909e+00, 7.45391115e+00, 7.61656564e-01, 7.37219347e-02,
#         6.60778277e-03, 4.82334671e-04],
#        [1.18181818e+00, 8.28286758e+00, 1.21277213e+00, 2.60522199e-01,
#         3.87223027e-02, 7.03598959e-03],
#        [1.27272727e+00, 7.61303021e+00, 1.81005756e+00, 3.52075303e-01,
#         8.37075579e-02, 3.15814521e-02],
#        [1.36363636e+00, 6.31537918e+00, 2.25440468e+00, 6.99869349e-01,
#         1.59682183e-01, 8.52162442e-02],
#        [1.45454545e+00, 7.60029359e+00, 2.53934763e+00, 1.00050901e+00,
#         3.01052446e-01, 2.08922107e-01],
#        [1.54545455e+00, 5.38910939e+00, 2.35260007e+00, 8.49514531e-01,
#         3.69980464e-01, 3.06653894e-01],
#        [1.63636364e+00, 5.41140224e+00, 2.98080193e+00, 1.20718732e+00,
#         6.36913521e-01, 4.75265940e-01],
#        [1.72727273e+00, 4.56449516e+00, 2.01172053e+00, 1.32967397e+00,
#         6.53568960e-01, 5.78270309e-01],
#        [1.81818182e+00, 3.53071936e+00, 2.00169360e+00, 1.17378690e+00,
#         8.68272208e-01, 9.88267376e-01]])

# %%
# Calculate residuals
residualsArr = LINEAR_PATHWAY_ARR - modelArr
# Recover the time
residualsArr[:, 0] = modelArr[:, 0]
# Look at the data
residualsArr[0:10, :]
# Out:
#  [[       1,    -1.48322,           0,          0,           0,            0],
#   [ 1.09091,     -1.6771,  -0.0318214, 0.00476927, 0.000615846, -8.79153e-05],
#   [ 1.18182,  -0.0546616,   -0.173318,  0.0300888, 0.000413433, -0.000602659],
#   [ 1.27273, 2.63468e-05, -0.00716352, -0.0816947,  -0.0198331, -0.000882938],
#   [ 1.36364,    -0.63606,    0.135216,  0.0538218,  -0.0372692,  -0.00115709],
#   [ 1.45455,     1.25293,    0.220887,   0.153659, -0.00827052,    0.0309197],
#   [ 1.54545,   -0.406673,  -0.0840728,  -0.174916,  -0.0607119,  -0.00576749],
#   [ 1.63636,    0.119269,    0.489336,  0.0342381,   0.0847052,   -0.0159773],
#   [ 1.72727,   -0.267756,   -0.485465,  0.0391899,  -0.0133198,     -0.13492],
#   [ 1.81818,   -0.881612,   -0.463771,  -0.203834,   0.0985045,    0.0134523]]

# %%
# Let's put this together into a single function that we can use later
def calcResiduals(modelStr, observedArr, parameterDct, startTime=1, endTime=10):
    """
    Calculates the residuals for parameter assignments for a model given the observed values.

    Parameters
    ----------
    modelStr: str
        Antimony model
    observedArr: np.array
        matrix of observed values; first column is time
    parameterDct: dict
        key: parameter name
        value: parameter value
    startTime: int
    endTime: int

    Returns
    -------
    np.array
        col 0: time
        col 1-: float
    """
    # Create the Roadrunner object
    rr = te.loada(modelStr)
    # Assign values to the kinetic constants
    for name in parameterDct.keys():
        rr[name] = parameterDct[name]
    # Run the simulation
    modelArr = rr.simulate(startTime, endTime, 10*endTime)
    # Calculate residuals
    residualsArr = observedArr - modelArr
    residualsArr[:, 0] = modelArr[:, 0] # recover time
    #
    return residualsArr

# TESTS
residualsArr = calcResiduals(LINEAR_PATHWAY_MODEL, LINEAR_PATHWAY_ARR, 
                             PARAMETER_DCT)
assert(len(residualsArr) > 0)
assert("NamedArray" in str(type(residualsArr)))

# %%
# Plot the result with separate plots for each species
columnNames = ["S1", "S2", "S3", "S4", "S5"]
fig = plt.figure(figsize=(12, 8))
numCol = 3
numRow = 2
# Use a customized plotting grid to avoid getting an empty plot
spec = gridspec.GridSpec(ncols=numCol, nrows=numRow, figure=fig)
# Do the plot
times = residualsArr[:, 0]
for idx, name in enumerate(columnNames):
    if idx < numCol:
        irow = 0
        icol = idx
    else:
        irow = 1
        icol = idx - numCol
    ax = fig.add_subplot(spec[irow, icol])
    ax.scatter(times, residualsArr[:, idx+1])
    title = name[1:-1] # Delete the square brackets around the species name
    ax.set_title(title)
    ax.set_ylim([-10, 10])

# %% [markdown]
# ## (2) Evaluate possible fits for k1

# %%
k1Vals = [n*0.2 for n in range(21)]
parameterName = "k1"
rsqDct = {} # Container for the simulation results
for k1Val in k1Vals:
    parameterDct = dict(PARAMETER_DCT)
    parameterDct[parameterName] = k1Val
    residualsArr = calcResiduals(LINEAR_PATHWAY_MODEL, LINEAR_PATHWAY_ARR,
                                 parameterDct)
    rsqDct[k1Val] = sum(sum(residualsArr**2))

# %%
# Look at the result
rsqDct
# Out:
# {0.0: 19086.484006419174,
#  0.2: 6556.518315938366,
#  0.4: 4544.02587680233,
#  0.6000000000000001: 4020.6562676528015,
#  0.8: 3858.671270650337,
#  1.0: 3818.7678452090317,
#  1.2000000000000002: 3827.3999717264733,
#  1.4000000000000001: 3856.4648285229077,
#  1.6: 3893.7902333276493,
#  1.8: 3933.717310571698,
#  2.0: 3973.5290813284473,
#  2.2: 4011.9280836959592,
#  2.4000000000000004: 4048.331829994884,
#  2.6: 4082.526817638539,
#  2.8000000000000003: 4114.490930487699,
#  3.0: 4144.299432111724,
#  3.2: 4172.074291651174,
#  3.4000000000000004: 4197.956511551074,
#  3.6: 4222.091075608333,
#  3.8000000000000003: 4244.6188687475005,
#  4.0: 4265.673103645444}

# %%
list(rsqDct.keys())
# Out:
# [0.0,
#  0.2,
#  0.4,
#  0.6000000000000001,
#  0.8,
#  1.0,
#  1.2000000000000002,
#  1.4000000000000001,
#  1.6,
#  1.8,
#  2.0,
#  2.2,
#  2.4000000000000004,
#  2.6,
#  2.8000000000000003,
#  3.0,
#  3.2,
#  3.4000000000000004,
#  3.6,
#  3.8000000000000003,
#  4.0]

# %%
# Construct a plot
plt.plot(list(rsqDct.keys()), list(rsqDct.values()))
plt.xlabel("k1")
plt.ylabel("RSQ")
plt.title("Evaluation of k1 fits")
# Out:
# Text(0.5, 1.0, 'Evaluation of k1 fits')

# %% [markdown]
# The true parameter value occurs at the ``k1`` value that has the lowest RSQ, about 1.0.

# %% [markdown]
# ## (3) Simple Fitting Algorithm

# %% [markdown]
#     resultDct = {}
#     for values in possibleValueAssignments
#         parameterDct = assign values to parameters
#         rsq = sum(calculateResiduals(parameterDct)
#         resultDct[parameterDct] = rsq
#     fittedParameters = parameterDct in resultDct that minimizes rsq

# %% [markdown]
# For $N$ parameters each of which has $M$ different values to explore (levels), the ``for`` loop iterates $M^N$ times.
# For example, if there are 10 parameters each with 10 values, this is $10^{10}$!

# %% [markdown]
# # Exercise 2: Optimization

# %% [markdown]
# 1. Apply ``scipy.optimize.minimize`` to the ``LINEARY_PATHWAY_MODEL`` to find values of the parameters ``k1, k2, k3, k4`` that minimize the sum of squares of the residuals for ``LINEAR_PATHWAY_DF``. *Hint*: Create a function that takes as input the values of the parameters of ``LINEAR_PATHWAY_MODEL`` and outputs the sum of squares of the residuals.
#
# 2. Questions
#     1. How well does gradient descent do? Differential evolution?
#     1. What happens when you use large bounds, say an upper bound of 1,000?

# %% [markdown]
# ## Function to minimize

# %% [markdown]
# We begin by constructing the function to minimize. This is the equivalent to the ``distance`` function in the ``Optimization`` notebook.
# We take advantage of the ``calcResiduals`` function that
# calculates the residuals for a simulation of ``LINEAR_PATHWAY_MODEL``.

# %%
def functionToMinimize(parameterValues):
    """
    Parameters
    ----------
    parameterValues: list-float
        k1, k2, k3, k4
    """
    parameterDct = {"k%d" % (n + 1): parameterValues[n] for n in range(len(parameterValues))}
    residualsArr = calcResiduals(LINEAR_PATHWAY_MODEL, LINEAR_PATHWAY_ARR, parameterDct)
    return np.sum(residualsArr**2)

# TESTS
ssr1 = functionToMinimize([1, 2, 3, 4])
ssr2 = functionToMinimize([1, 1,  1, 1])
assert(ssr2 > ssr1)

# %% [markdown]
# ## Do the minimization

# %%
from scipy.optimize import LinearConstraint

eye2Mat = np.identity(4) # Two dimensional identity matrix

constraints = LinearConstraint(eye2Mat, [0, 0, 0 , 0], [10, 10, 10, 10]),

# %%
# Optimization using gradient descent
from scipy.optimize import minimize

res = minimize(
    functionToMinimize,
    constraints=constraints,
    x0=(0, 0, 0, 0),
)

res.x
# Out:
# array([1.01353894, 2.15811087, 3.07934494, 4.2804306 ])

# %%
# Optimization using differential evolution
from scipy.optimize import differential_evolution

bounds = [(0, 10) for _ in range(4)]

res = differential_evolution(
    functionToMinimize,
    bounds=bounds,
)

res.x
# Out:
# array([1.01352126, 2.15811874, 3.0795098 , 4.28026525])

# %% [markdown]
# ## Specific questions
# 1. Both gradient descent and differential evolution return resonable estimates of parameter values.
# 1. Larger bounds, like 1000, result in really bad parameter estimates.

# %% [markdown]
# # Exercise 3: Fitting Glycolytic Oscillations

# %% [markdown]
# This exercise is about fitting parameters in the Wolf model for glycolytic oscillations.
# The model is ``WOLF_MODEL`` and the observational data for this model are ``WOLF_DF``.
#
# 1. Implement a ``doFit`` function that encapsulates the workflow for the Wolf model.
# 1. Try fitting the model using ``WOLF_PARAMETERS``. First try ``leastSquares`` (a graident descent method) and then ``differential_evolution``. How did the two methods differ as to fitting time and quality? Why? What would you try next to get better fits?
# 1. Limit the parameter values so that the upper value is twice the true value. Try fits using leastsqs and differential evolution.

# %%
print(WOLF_MODEL)
# Out:
# // Created by libAntimony v2.12.0.3
# model *Jana_WolfGlycolysis()
#
#   // Compartments and Species:
#   compartment compartment_;
#   species Glucose in compartment_, fructose_1_6_bisphosphate in compartment_;
#   species glyceraldehyde_3_phosphate in compartment_, glycerate_3_phosphate in compartment_;
#   species pyruvate in compartment_, Acetyladehyde in compartment_, External_acetaldehyde in compartment_;
#   species ATP in compartment_, ADP in compartment_, NAD in compartment_, NADH in compartment_;
#   species $External_glucose in compartment_, $ethanol in compartment_, $Glycerol in compartment_;
#   species $Sink in compartment_;
#
#   // Reactions:
#   J0: $External_glucose => Glucose; J0_inputFlux;
#   J1: Glucose + 2 ATP => fructose_1_6_bisphosphate + 2 ADP; J1_k1*Glucose*ATP*(1/(1 + (ATP/J1_Ki)^J1_n));
#   J2: fructose_1_6_bisphosphate => glyceraldehyde_3_phosphate + glyceraldehyde_3_phosphate; J2_k*fructose_1_6_bisphosphate;
#   J3: glyceraldehyde_3_phosphate + NADH => NAD + $Glycerol; J3_k*glyceraldehyde_3_phosphate*NADH;
#   J4: glyceraldehyde_3_phosphate + ADP + NAD => ATP + glycerate_3_phosphate + NADH; (J4_kg*J4_kp*glyceraldehyde_3_phosphate*NAD*ADP - J4_ka*J4_kk*glycerate_3_phosphate*ATP*NADH)/(J4_ka*NADH + J4_kp*ADP);
#   J5: glycerate_3_phosphate + ADP => ATP + pyruvate; J5_k*glycerate_3_phosphate*ADP;
#   J6: pyruvate => Acetyladehyde; J6_k*pyruvate;
#   J7: Acetyladehyde + NADH => NAD + $ethanol; J7_k*Acetyladehyde*NADH;
#   J8: Acetyladehyde => External_acetaldehyde; J8_k1*Acetyladehyde - J8_k2*External_acetaldehyde;
#   J9: ATP => ADP; J9_k*ATP;
#   J10: External_acetaldehyde => $Sink; J10_k*External_acetaldehyde;
#
#   // Species initializations:
#   Glucose = 0;
#   fructose_1_6_bisphosphate = 0;
#   glyceraldehyde_3_phosphate = 0;
#   glycerate_3_phosphate = 0;
#   pyruvate = 0;
#   Acetyladehyde = 0;
#   External_acetaldehyde = 0;
#   ATP = 3;
#   ADP = 1;
#   NAD = 0.5;
#   NADH = 0.5;
#   External_glucose = 0;
#   ethanol = 0;
#   Glycerol = 0;
#   Sink = 0;
#
#   // Compartment initializations:
#   compartment_ = 1;
#
#   // Variable initializations:
#   J0_inputFlux = 50;
#   J1_k1 = 550;
#   J1_Ki = 1;
#   J1_n = 4;
#   J2_k = 9.8;
#   J3_k = 85.7;
#   J4_kg = 323.8;
#   J4_kp = 76411.1;
#   J4_ka = 57823.1;
#   J4_kk = 23.7;
#   J5_k = 80;
#   J6_k = 9.7;
#   J7_k = 2000;
#   J8_k1 = 375;
#   J8_k2 = 375;
#   J9_k = 28;
#   J10_k = 80;
#
#   // Other declarations:
#   const compartment_, J0_inputFlux, J1_k1, J1_Ki, J1_n, J2_k, J3_k;
#   const J4_kg, J4_kp, J4_ka, J4_kk, J5_k, J6_k, J7_k, J8_k1, J8_k2;
#   const J9_k, J10_k;
# end

# %%
# Parameter ranges and initial value
upper = 1e5
WOLF_PARAMETERS = [
      SBstoat.Parameter("J1_k1", lower=0, value=1, upper=upper), #550
      SBstoat.Parameter("J1_Ki", lower=0, value=1, upper=upper), #1
      SBstoat.Parameter("J1_n", lower=0, value=1, upper=upper), #4
      SBstoat.Parameter("J2_k", lower=0, value=1, upper=upper), #9.8
      SBstoat.Parameter("J3_k", lower=0, value=1, upper=upper), #85.7
      SBstoat.Parameter("J4_kg", lower=0, value=1, upper=upper), #323.8
      SBstoat.Parameter("J4_kp", lower=0, value=1, upper=upper), #76411.1
      SBstoat.Parameter("J4_ka", lower=0, value=1, upper=upper), #57823.1
      SBstoat.Parameter("J4_kk", lower=0, value=1, upper=upper), #23.7
      SBstoat.Parameter("J5_k", lower=0, value=1, upper=upper), #80
      SBstoat.Parameter("J6_k", lower=0, value=1, upper=upper), #9.7
      SBstoat.Parameter("J7_k", lower=0, value=1, upper=upper), #2000
      SBstoat.Parameter("J8_k1", lower=0, value=1, upper=upper), #375
      SBstoat.Parameter("J8_k2", lower=0, value=1, upper=upper), #375
      SBstoat.Parameter("J9_k", lower=0, value=1, upper=upper), #28
      SBstoat.Parameter("J10_k", lower=0, value=1, upper=upper), #80                                                                                                                                                                          
]

# %% [markdown]
# ## (1) Encapsulate workflow

# %% [markdown]
# As before, we encapsulate our workflow in a ``doFit`` function. There is one subtly included here - the argument to ``fitModel``
# has ``max_nfev`` set to ``None``. This value is passed to ``lmfit``, and instruct those codes to use an unlimited number
# of iterations to converge.
# This is useful in more complex models, but it can come at the cost of increased computation times.

# %%
def doFit(endTime=5, fitterMethods=["leastsq"], parametersToFit=WOLF_PARAMETERS,
          isTest=False):
    """
    Fit the Wolf Model.

    Parameters
    ----------
    endTime: float
    fitterMethods: list-str
    parametersToFit: list-SBstoat.Parameter

    Returns
    -------
    ModelFitter
    """
    model = te.loada(WOLF_MODEL)
    observedTS = NamedTimeseries(dataframe=WOLF_DF)
    # Find the last index to use
    lastIdx = len([t for t in observedTS[TIME] if t <= endTime])
    observedTS = observedTS[:lastIdx]
    # Construct the fitter and do the fit
    fitter = ModelFitter(model, observedTS, fitterMethods=fitterMethods, 
                         parametersToFit=parametersToFit)
    fitter.fitModel()
    if not isTest:
        print(fitter.reportFit())
        fitter.plotFitAll(figsize=(24,16), numCol=2, color=["red", "blue"])
    return fitter

# TESTS
result = doFit(isTest=True)
assert(isinstance(result, ModelFitter))
# Out:
# 14307.611639:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))

# %% [markdown]
# ## (2) Fit model

# %%
# Least squares fit
fitter = doFit(fitterMethods=["leastsq"])
# Out:
# 14441.405870:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
# [[Variables]]
#     J1_k1:  38.27600396768341
#     J1_Ki:  124.93983313666301
#     J1_n:  57.06034366085568
#     J2_k:  9.06887464373473
#     J3_k:  22.355816168664134
#     J4_kg:  47.898028820420734
#     J4_kp:  882.8447998503658
#     J4_ka:  1293.0291296522007
#     J4_kk:  1.4218674054329041
#     J5_k:  124.80881319320166
#     J6_k:  10.393235051711605
#     J7_k:  693.6383675535146
#     J8_k1:  8.57489054505365
#     J8_k2:  23.14648206570958
#     J9_k:  33.29595132089058
#     J10_k:  13.703701315720963
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 180
#     # data points      = 5500
#     # variables        = 16
#     chi-square         = 38211.8382
#     reduced chi-square = 6.96787713
#     Akaike info crit   = 10693.1850
#     Bayesian info crit = 10798.9851
# ##  Warning: uncertainties could not be estimated:

# %%
# Differential evolution
doFit(fitterMethods=["differential_evolution"])
# Out:
# Streaming output truncated to the last 5000 lines.
# 14573.964137:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14573.990564:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14573.994420:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14573.997838:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.001666:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.022179:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.028871:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.032208:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.035505:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.043092:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.055932:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.059244:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.062473:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.065604:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.073374:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.076656:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.090273:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.103528:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.106942:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.110683:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.122451:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.125833:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.129073:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.132668:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.144456:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.149194:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.152682:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.155861:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.159003:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.168848:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.172147:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.181746:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.191629:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.195029:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.212040:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.215429:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.218749:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.237125:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.249162:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.267805:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.271924:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.280259:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.284124:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.287923:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.310510:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.321295:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.327483:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.330904:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.334371:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.344232:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.347676:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.351038:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.354072:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.368218:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.371836:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.375721:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.393451:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.396677:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.399761:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.413054:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.443530:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.466339:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.478074:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.488358:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.491883:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.495186:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.508013:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.511439:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.514691:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.528194:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.537529:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.541169:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.544534:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.560896:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.572613:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.576118:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.588789:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.593904:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.605391:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.609030:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.612743:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.616367:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.619823:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.632654:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.636213:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.639579:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.642982:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.660527:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.665431:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.683457:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.687184:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.690481:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.695266:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.700448:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.710868:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.714861:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.724109:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.734996:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.743163:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.746952:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.753465:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.764492:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.768118:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.771807:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.775207:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.782079:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.794377:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.798223:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.802123:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.806080:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.809999:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.830535:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.840922:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.845298:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.854401:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.878747:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.883135:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.887296:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.899791:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.903366:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.909972:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.913736:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.927884:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.931812:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.935459:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.952050:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.957213:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.973197:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.976808:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.983871:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14574.994905:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.016269:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.019958:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.033544:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.038461:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.059014:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.085445:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.089343:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.128284:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.133173:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.136512:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.140232:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.144630:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.148241:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.151597:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.155915:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.165917:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.169957:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.173800:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.194663:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.198556:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.202388:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.217488:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.256450:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.275592:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.283027:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.304005:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.315525:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.320560:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.326355:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.329884:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.352999:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.364017:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.369254:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.373381:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.376882:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.390257:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.401865:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.405634:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.410699:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.421930:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.425401:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.429070:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.437984:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.452717:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.461519:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.471188:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.481703:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.504795:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.508479:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14575.517939:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# ...
#
# 14611.604841:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14611.624847:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14611.643070:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14611.650253:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14611.740956:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14611.751120:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14611.852658:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14611.872083:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14611.991248:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14612.127481:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14612.176906:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14612.314658:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14612.799911:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14612.874932:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14612.971565:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14613.182086:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14613.383303:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14613.445138:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14613.504256:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14613.523322:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14613.565161:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14613.616982:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14614.084955:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14614.520614:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14614.617295:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14614.745498:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14614.878377:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14614.960709:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14620.659440:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14620.916197:     (Roadrunner exception: : CVODE Error: CV_ERR_FAILURE: Error test failures occurred too many times (= MXNEF = 7) during one internal time step oroccurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14623.263956:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14623.385305:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14624.085441:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14624.826423:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14624.902877:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14625.759072:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14628.743198:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14634.210818:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14637.437965:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14637.671569:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14644.081414:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14653.425929:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14659.050577:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14666.329412:     (Roadrunner exception: : CVODE Error: CV_ERR_FAILURE: Error test failures occurred too many times (= MXNEF = 7) during one internal time step oroccurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14672.031954:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14674.076405:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14679.111665:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14685.155879:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14696.979276:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14705.986894:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14708.588864:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14711.957520:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14712.280274:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14713.493685:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14715.693527:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14715.701814:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
# [[Variables]]
#     J1_k1:  30.579961702579638
#     J1_Ki:  56191.40838559578
#     J1_n:  5050.015401794087
#     J2_k:  10.447387749351874
#     J3_k:  1124.817510534064
#     J4_kg:  87236.08282480935
#     J4_kp:  87116.38264753918
#     J4_ka:  10211.875100123925
#     J4_kk:  97230.38045922204
#     J5_k:  51.63710010899678
#     J6_k:  8.775155636784447
#     J7_k:  85854.50051923539
#     J8_k1:  22510.204756471197
#     J8_k2:  99535.16770245942
#     J9_k:  18.764069262472695
#     J10_k:  32290.44606310391
# [[Fit Statistics]]
#     # fitting method   = differential_evolution
#     # function evals   = 34001
#     # data points      = 5500
#     # variables        = 16
#     chi-square         = 9105.59362
#     reduced chi-square = 1.66039271
#     Akaike info crit   = 2804.77449
#     Bayesian info crit = 2910.57454
# ##  Warning: uncertainties could not be estimated:
#     this fitting method does not natively calculate uncertainties
#     and numdifftools is not installed for lmfit to do this. Use
#     `pip install numdifftools` for lmfit to estimate uncertainties
#     with this fitting method.

# %% [markdown]
# ### Questions
# 1. Differential evoluation takes a lot longer than leastsq. Neither method produced partiularly good fits, especially for the oscillations.
#
# 1. We'd probably want to limit the parameter ranges of each parameter based on the scientific literature.

# %% [markdown]
# ## (3) Limit parameter ranges

# %%
parametersToFit = [
      SBstoat.Parameter("J1_k1", lower=0, value=1, upper=1100), #550
      SBstoat.Parameter("J1_Ki", lower=0, value=1, upper=2), #1
      SBstoat.Parameter("J1_n", lower=0, value=1, upper=8), #4
      SBstoat.Parameter("J2_k", lower=0, value=1, upper=20), #9.8
      SBstoat.Parameter("J3_k", lower=0, value=1, upper=160), #85.7
      SBstoat.Parameter("J4_kg", lower=0, value=1, upper=660), #323.8
      SBstoat.Parameter("J4_kp", lower=0, value=1, upper=150000), #76411.1
      SBstoat.Parameter("J4_ka", lower=0, value=1, upper=110000), #57823.1
      SBstoat.Parameter("J4_kk", lower=0, value=1, upper=46), #23.7
      SBstoat.Parameter("J5_k", lower=0, value=1, upper=160), #80
      SBstoat.Parameter("J6_k", lower=0, value=1, upper=20), #9.7
      SBstoat.Parameter("J7_k", lower=0, value=1, upper=4000), #2000
      SBstoat.Parameter("J8_k1", lower=0, value=1, upper=750), #375
      SBstoat.Parameter("J8_k2", lower=0, value=1, upper=750), #375
      SBstoat.Parameter("J9_k", lower=0, value=1, upper=56), #28
      SBstoat.Parameter("J10_k", lower=0, value=1, upper=160), #80                                                                                                                                                                          
]

# %%
doFit(fitterMethods=["leastsqs"], parametersToFit=parametersToFit)
# Out:
# [[Variables]]
#     J1_k1:  45.957683350709196
#     J1_Ki:  0.6314812658070119
#     J1_n:  1.0367407357769165
#     J2_k:  11.944073653446429
#     J3_k:  46.26834939424841
#     J4_kg:  646.8997477246164
#     J4_kp:  146161.59577429658
#     J4_ka:  152.8037807351751
#     J4_kk:  0.7879889578934712
#     J5_k:  159.6922702201876
#     J6_k:  10.792331438008173
#     J7_k:  997.1976371997688
#     J8_k1:  594.8470972010213
#     J8_k2:  509.91695293634353
#     J9_k:  29.754173456548525
#     J10_k:  11.292187159979738
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 257
#     # data points      = 5500
#     # variables        = 16
#     chi-square         = 4941.55164
#     reduced chi-square = 0.90108527
#     Akaike info crit   = -556.877918
#     Bayesian info crit = -451.077864
# [[Correlations]] (unreported correlations are < 0.100)
#     C(J4_kk, J6_k)  = -0.676
#     C(J4_kg, J4_kp) =  0.645
#     C(J3_k, J8_k1)  = -0.634
#     C(J2_k, J6_k)   =  0.490
#     C(J2_k, J4_kk)  = -0.452
#     C(J1_Ki, J4_ka) = -0.407
#     C(J1_Ki, J4_kk) =  0.376
#     C(J3_k, J9_k)   = -0.374
#     C(J3_k, J4_kg)  =  0.371
#     C(J4_kp, J10_k) = -0.368
#     C(J5_k, J7_k)   = -0.346
#     C(J4_ka, J7_k)  = -0.337
#     C(J4_kp, J8_k2) = -0.335
#     C(J6_k, J7_k)   = -0.334
#     C(J8_k2, J10_k) = -0.326
#     C(J1_Ki, J3_k)  = -0.324
#     C(J1_k1, J5_k)  = -0.320
#     C(J4_kk, J8_k1) =  0.305
#     C(J4_kg, J7_k)  =  0.301
#     C(J3_k, J4_kp)  =  0.296
#     C(J4_kg, J10_k) = -0.291
#     C(J3_k, J6_k)   =  0.290
#     C(J1_n, J10_k)  =  0.279
#     C(J1_Ki, J8_k1) =  0.278
#     C(J1_Ki, J4_kg) = -0.264
#     C(J1_Ki, J7_k)  = -0.248
#     C(J1_k1, J4_kp) =  0.243
#     C(J4_kp, J7_k)  =  0.240
#     C(J4_kg, J8_k2) = -0.228
#     C(J4_kg, J9_k)  =  0.221
#     C(J4_kk, J9_k)  =  0.206
#     C(J1_k1, J4_ka) =  0.197
#     C(J3_k, J4_kk)  = -0.182
#     C(J4_ka, J6_k)  =  0.178
#     C(J3_k, J4_ka)  =  0.175
#     C(J1_k1, J1_Ki) = -0.173
#     C(J7_k, J8_k2)  = -0.171
#     C(J6_k, J8_k1)  = -0.168
#     C(J3_k, J8_k2)  = -0.162
#     C(J1_n, J5_k)   =  0.158
#     C(J4_ka, J8_k1) = -0.150
#     C(J3_k, J5_k)   = -0.148
#     C(J1_n, J7_k)   =  0.143
#     C(J4_kp, J6_k)  =  0.140
#     C(J1_k1, J2_k)  = -0.140
#     C(J1_Ki, J10_k) = -0.139
#     C(J1_k1, J1_n)  =  0.139
#     C(J1_Ki, J2_k)  = -0.136
#     C(J2_k, J5_k)   = -0.133
#     C(J4_kg, J8_k1) = -0.129
#     C(J1_Ki, J4_kp) = -0.129
#     C(J1_Ki, J9_k)  =  0.123
#     C(J4_kg, J5_k)  =  0.121
#     C(J2_k, J3_k)   =  0.116
#     C(J4_kp, J4_kk) = -0.110
#     C(J8_k1, J8_k2) =  0.109
#     C(J4_kg, J4_ka) = -0.107
#     C(J2_k, J8_k1)  =  0.106
#     C(J5_k, J6_k)   = -0.105
#     C(J1_n, J2_k)   =  0.104
#     C(J1_k1, J3_k)  = -0.103
#     C(J1_k1, J7_k)  = -0.103
#     C(J1_k1, J6_k)  = -0.101

# %%
doFit(fitterMethods=["differential_evolution"], parametersToFit=parametersToFit)
# Out:
# 14088.693327:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14088.821164:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14088.937995:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14089.096489:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14089.157262:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14089.500153:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14089.926199:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14090.108658:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14090.145686:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14090.364403:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14090.427824:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14090.821474:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14091.408574:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14092.329523:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14092.845570:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14093.093465:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14093.157456:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14093.550375:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14094.499535:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14094.565449:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14096.664279:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14099.417417:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14099.431874:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14107.452081:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14108.228959:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14108.573629:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14108.923065:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14112.100553:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14112.389738:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14112.974801:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14113.736466:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14113.832380:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14114.595748:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14115.155651:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14115.471480:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14115.504092:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14115.880616:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14117.258619:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14118.300407:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14118.896687:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14118.929769:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14119.219371:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14119.360066:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14119.410559:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14119.591820:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14119.676272:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14119.710903:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14119.737463:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14119.914125:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14124.928020:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14125.939798:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14129.762724:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14138.336553:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14139.859074:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14139.996086:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14145.593037:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14149.479617:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14170.175359:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14170.467146:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14178.442139:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14180.488344:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14181.495791:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14186.826270:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14192.751355:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14196.103270:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14198.528990:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14202.537473:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14203.765258:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14204.872214:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14205.610892:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14205.788870:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14206.494639:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14209.276395:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14214.909404:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14219.102614:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14237.570627:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14237.648081:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14238.250390:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14238.577674:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14250.656876:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14250.769978:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14254.085459:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14255.144023:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14256.413257:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14257.089496:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14259.949341:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14260.865476:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14262.456069:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14263.804483:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14270.138380:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14274.717555:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14285.856870:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14289.126086:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14300.945030:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14301.625695:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 14302.815351:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
# [[Variables]]
#     J1_k1:  83.12175649987017
#     J1_Ki:  1.9296659028318353
#     J1_n:  4.968677150231278
#     J2_k:  10.313224867302058
#     J3_k:  51.79250987654572
#     J4_kg:  495.4887543743316
#     J4_kp:  102438.7531034129
#     J4_ka:  106295.30708348245
#     J4_kk:  34.00826477499218
#     J5_k:  120.79681676282794
#     J6_k:  10.186565399041909
#     J7_k:  2581.3362644172116
#     J8_k1:  170.0874984102194
#     J8_k2:  319.268466021801
#     J9_k:  29.11974326346303
#     J10_k:  129.03847496987495
# [[Fit Statistics]]
#     # fitting method   = differential_evolution
#     # function evals   = 34001
#     # data points      = 5500
#     # variables        = 16
#     chi-square         = 6389.08987
#     reduced chi-square = 1.16504192
#     Akaike info crit   = 856.140547
#     Bayesian info crit = 961.940601
# ##  Warning: uncertainties could not be estimated:
#     this fitting method does not natively calculate uncertainties
#     and numdifftools is not installed for lmfit to do this. Use
#     `pip install numdifftools` for lmfit to estimate uncertainties
#     with this fitting method.
