# %% [markdown]
# # CROSS VALIDATION: IMPLEMENTATION
#
# This notebook describes how to do cross validation for simulation models.
#
# Cross validation partitions the observed data into *folds*.
# A fold consists of a pair of training data and test data.
# For simulation models,
# the training data are used to estimate parameters, and the quality of these estimates is evaluated based on predictions of the test data.
#
# The main challenges with cross validation for simulation data are: creating folds, estimating parameters on data subsets, and evaluating parameter estimates on a data subset.

# %% [markdown]
# # Programming Preliminaries

# %%
IS_COLAB = True

# %%
if IS_COLAB:
    # !pip install -q tellurium
    # !pip install -q SBstoat
    pass
# Out:
#      |████████████████████████████████| 122kB 4.1MB/s
#      |████████████████████████████████| 5.8MB 5.6MB/s
#      |████████████████████████████████| 14.9MB 192kB/s
#      |████████████████████████████████| 6.2MB 19.9MB/s
#      |████████████████████████████████| 36.7MB 84kB/s
#      |████████████████████████████████| 28.5MB 122kB/s
#      |████████████████████████████████| 2.5MB 34.0MB/s
#      |████████████████████████████████| 16.6MB 155kB/s
#      |████████████████████████████████| 3.1MB 28.7MB/s
#      |████████████████████████████████| 2.0MB 28.5MB/s
#      |████████████████████████████████| 3.2MB 27.3MB/s
#      |████████████████████████████████| 5.6MB 14.3MB/s
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
#      |████████████████████████████████| 28.1MB 99kB/s
#      |████████████████████████████████| 307kB 31.1MB/s
#      |████████████████████████████████| 163kB 28.4MB/s
#      |████████████████████████████████| 102kB 9.9MB/s
#   Building wheel for SBstoat (setup.py) ... done
#   Building wheel for lmfit (setup.py) ... done
#   Building wheel for docstring-expander (setup.py) ... done
#   Building wheel for asteval (setup.py) ... done

# %%
# %matplotlib inline
import tellurium as te
import numpy as np
import math
import random 
import matplotlib.pyplot as plt
from SBstoat import ModelFitter, NamedTimeseries, Parameter

# %%
import urllib
def getSharedCodes(moduleName):
  """
  Obtains common codes from the github repository.

  Parameters
  ----------
  moduleName: str
      name of the python module in the src directory
  """
  if IS_COLAB:
      url = "https://github.com/sys-bio/network-modeling-summer-school-2021/raw/main/src/%s.py" % moduleName
      local_python = "python.py"
      _, _ = urllib.request.urlretrieve(url=url, filename=local_python)
  else:
      local_python = "../../src/%s.py" % moduleName
  with open(local_python, "r") as fd:
    codeStr = "".join(fd.readlines())
  print(codeStr)
  exec(codeStr, globals())

# Acquire codes
getSharedCodes("util")

# TESTS
assert(isinstance(LINEAR_PATHWAY_DF, pd.DataFrame))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-79d0e61ad29a> in <module>()
#      21
#      22 # Acquire codes
# ---> 23 getSharedCodes("util")
#      24
#      25 # TESTS
#
# <ipython-input-1-79d0e61ad29a> in getSharedCodes(moduleName)
#       9       name of the python module in the src directory
#      10   """
# ---> 11   if IS_COLAB:
#      12       url = "https://github.com/sys-bio/network-modeling-summer-school-2021/raw/main/src/%s.py" % moduleName
#      13       local_python = "python.py"
#
# NameError: name 'IS_COLAB' is not defined

# %%
def findCloseMatchingValues(longArr, shortArr):
    """
    Finds the indices in longArr that are closest to the values in shortArr.

    Parameters
    ----------
    longArr: np.array
    shortArr: np.arry

    Returns
    -------
    array-int
    """
    indices = []
    for val in shortArr:
        distances = (longArr - val)**2
        minDistance = np.min(distances)
        distancesLst = list(distances)
        idx = distancesLst.index(minDistance)
        indices.append(idx)
    return np.array(indices)

# TESTS
longArr = np.array(range(10))
shortArr = np.array([2.1, 2.9, 4.3])
indexArr = findCloseMatchingValues(longArr, shortArr)
expectedArr = [2, 3, 4]
assert(all([v1 == v2 for v1, v2 in zip(indexArr, expectedArr)]))

# %%
# Experimental conditions
END_TIME = max(LINEAR_PATHWAY_ARR[:, 0])
NUM_POINT = 15
NOISE_STD = 1.0
NUM_FOLD = 3

# %% [markdown]
# # Constants

# %%
# Constants
FOLD_TRAINING = 0 # Training data in a fold
FOLD_TEST = 1 # Test data in a fold
RSQ = "rsq" # R-squared value in a dataframe

# %% [markdown]
# # Model

# %%
print(LINEAR_PATHWAY_MODEL)
# Out:
# R1:  S1 -> S2; k1*S1
# R2: S2 -> S3; k2*S2
# R3: S3 -> S4; k3*S3
# R4: S4 -> S5; k4*S4
#
# S1 = 10
#
# // Parameters
# k1 = 0; # Nominal value of parameter
# k2 = 0; # Nominal value of parameter
# k3 = 0; # Nominal value of parameter
# k4 = 0; # Nominal value of parameter

# %% [markdown]
# # Helper Functions

# %% [markdown]
# The following functions provide capabilities used in this notebook.

# %%
def runSimulation(simTime=END_TIME, numPoint=NUM_POINT, roadRunner=None,
                  parameterDct=None, model=LINEAR_PATHWAY_MODEL):
    """
    Runs the simulation model for the parameters.
   
    Parameters
    ----------
    endTime: float
        End time for the simulation
    numPoints: int
        Number of points in the simulation
    roadRunner: ExtendedRoadRunner
    parameters: list-str
        
    Returns
    -------
    NamedArray
        results of simulation
    """
    if roadRunner is None:
        roadRunner = te.loada(model)
    else:
        roadRunner.reset()
    if parameterDct is not None:
        # Set the simulation constants for all parameters
        for name in parameterDct.keys():
            roadRunner[name] = parameterDct[name]
    return roadRunner.simulate (0, simTime, numPoint)

# TESTS
numPoint = int(10*END_TIME)
fittedData = runSimulation(parameterDct={"k1": 0.1}, numPoint=numPoint)
numCol = np.shape(fittedData)[1]
assert(np.size(fittedData) == numPoint*numCol)
assert(fittedData[0, 1] == 10)

# %%
FITTED_DATA = runSimulation(parameterDct={"k1": 0.1}, numPoint=numPoint)

# %% [markdown]
# # Cross Validation Algorithm

# %% [markdown]
# Cross validation divides the data into training and test sets.
# The training sets are used to estimate parameters.
# The test sets are used to evaluate the quality of the
# parameter fits.
# That is, for each set of test indices, we have a companion set of training indices. The training indices select a subset of the observational data that are used to estimate parameter values.
#
# Below is pseudo code that calculates the $R^2$ value for each fold.
#
#     def crossValidate(model, observedData, numFold):
#         folds = generateFolds(observedData, numFold)
#         foldQualities = []
#         for fold folds:
#             foldQuality = evaluateFold(model, fold)
#             foldQualities.append(foldQuality)
#         return foldQualities

# %% [markdown]
# # Generating Folds

# %% [markdown]
# The first step is to generate the folds.
# A fold is represented by a tuple.
# The first element is the training data;
# the second element is the test data.
# The collection of these tuples is itsself an array.
# ``generateFolds`` such an array.

# %%
def generateFolds(observedData, numFold):
    """
    Generates indices of training and test data
    by alternating between folds
    
    Parameters:
    ----------
    observedData: np.array(N, M) or NamedTimeseries
    numFold: int
        number of pairs of testIndices and trainIndices
    
    Returns:
    --------
    array-tuple(array, array)
    """
    if isinstance(observedData, NamedTimeseries):
        df = observedData.to_dataframe()
        df = df.reset_index()
        observedData = df.to_numpy()
    result = []
    numPoint, numCol = np.shape(observedData)
    indices = range(numPoint)
    for remainder in range(numFold):
        testIndices = np.array([n for n in indices if n % numFold == remainder])
        testData = observedData[testIndices, :]
        trainIndices = np.array(list(set(indices).difference(testIndices)))
        trainData = observedData[trainIndices, :]
        entry = (trainData, testData)
        result.append(entry)
    return result

# TESTS
numFold = 3
observedData = NamedTimeseries(dataframe=LINEAR_PATHWAY_DF)
folds = generateFolds(observedData.to_dataframe().to_numpy(), numFold)
assert(len(folds) == numFold)
fold = folds[0]
assert(len(fold) == 2)
trainData = fold[0]
testData = fold[1]
assert(len(observedData) == (len(trainData) + len(testData)))
#
fold2s = generateFolds(observedData, numFold)
assert(len(folds) == len(fold2s))

# %%
folds
# Out:
# [(array([[7.45391115e+00, 7.61656564e-01, 7.37219347e-02, 6.60778277e-03,
#           4.82334671e-04],
#          [8.28286758e+00, 1.21277213e+00, 2.60522199e-01, 3.87223027e-02,
#           7.03598959e-03],
#          [6.31537918e+00, 2.25440468e+00, 6.99869349e-01, 1.59682183e-01,
#           8.52162442e-02],
#          [7.60029359e+00, 2.53934763e+00, 1.00050901e+00, 3.01052446e-01,
#           2.08922107e-01],
#          [5.41140224e+00, 2.98080193e+00, 1.20718732e+00, 6.36913521e-01,
#           4.75265940e-01],
#          [4.56449516e+00, 2.01172053e+00, 1.32967397e+00, 6.53568960e-01,
#           5.78270309e-01],
#          [3.27222225e+00, 2.26336096e+00, 1.41342726e+00, 8.08617233e-01,
#           1.19246083e+00],
#          [4.40101417e+00, 2.31026849e+00, 1.75426175e+00, 8.45330383e-01,
#           1.56057274e+00],
#          [3.12149948e+00, 1.96647005e+00, 1.66763659e+00, 9.53115806e-01,
#           2.03565210e+00],
#          [2.94982466e+00, 1.74039878e+00, 1.54935687e+00, 1.09908406e+00,
#           2.53792931e+00],
#          [2.29400209e+00, 1.52326497e+00, 1.14354984e+00, 8.92313164e-01,
#           3.98814301e+00],
#          [2.52774387e+00, 1.68323383e+00, 1.45689916e+00, 8.67941004e-01,
#           4.21028965e+00],
#          [1.89988352e+00, 1.56306037e+00, 1.16299395e+00, 8.45285916e-01,
#           4.54142844e+00],
#          [1.88436560e+00, 1.41775301e+00, 1.32178947e+00, 1.09165359e+00,
#           4.65395456e+00],
#          [1.32814906e+00, 1.14568460e+00, 1.10394608e+00, 7.52703863e-01,
#           6.60503076e+00],
#          [1.39013530e+00, 8.67187266e-01, 8.07416573e-01, 9.31501697e-01,
#           6.93539464e+00],
#          [1.23273582e+00, 7.57248110e-01, 9.51023224e-01, 6.19913546e-01,
#           7.21706425e+00],
#          [9.54094570e-01, 7.04054125e-01, 8.11931446e-01, 6.04317636e-01,
#           7.77139295e+00],
#          [8.46736355e-01, 5.80723287e-01, 7.19427285e-01, 5.62328022e-01,
#           6.52281615e+00],
#          [7.23451373e-01, 6.46316770e-01, 6.22587122e-01, 6.09046999e-01,
#           8.23291578e+00],
#          [6.39641075e-01, 6.16144366e-01, 6.12399719e-01, 4.33389295e-01,
#           8.10399358e+00],
#          [4.68324176e-01, 4.68416334e-01, 5.24484854e-01, 4.31285992e-01,
#           8.80400287e+00],
#          [4.41501520e-01, 4.60114954e-01, 4.18473049e-01, 4.06307836e-01,
#           8.57418445e+00],
#          [3.86486388e-01, 3.46606296e-01, 4.40065360e-01, 3.36602873e-01,
#           9.42591316e+00],
#          [2.82543470e-01, 3.56376226e-01, 3.00372788e-01, 2.60825441e-01,
#           9.39974289e+00],
#          [3.24146290e-01, 2.78879581e-01, 3.02855216e-01, 2.67707222e-01,
#           8.47746960e+00],
#          [3.00365686e-01, 2.64745098e-01, 2.80437013e-01, 2.34341241e-01,
#           7.90221935e+00],
#          [2.53870985e-01, 2.14917172e-01, 1.97012445e-01, 1.90597648e-01,
#           9.44831686e+00],
#          [1.62243658e-01, 2.02509147e-01, 1.76624896e-01, 1.75018506e-01,
#           8.39192016e+00],
#          [2.08222821e-01, 1.44498486e-01, 1.99124883e-01, 1.89523744e-01,
#           8.20376469e+00],
#          [1.44965201e-01, 1.22884927e-01, 1.29407582e-01, 1.53018715e-01,
#           1.09660503e+01],
#          [1.29426285e-01, 1.22502740e-01, 1.22182388e-01, 1.51320165e-01,
#           8.80866879e+00],
#          [1.01594352e-01, 1.05463754e-01, 1.08107256e-01, 1.03961259e-01,
#           1.12009653e+01],
#          [1.11395345e-01, 1.20500154e-01, 1.23133396e-01, 9.08308881e-02,
#           9.29572614e+00],
#          [8.32562710e-02, 7.41587181e-02, 9.03583743e-02, 8.62611523e-02,
#           9.43979194e+00],
#          [6.64073428e-02, 7.64403165e-02, 7.62690666e-02, 8.09490757e-02,
#           9.85694810e+00],
#          [5.59332641e-02, 6.21132981e-02, 7.11699375e-02, 7.37574496e-02,
#           1.16703506e+01],
#          [5.03753632e-02, 7.25572526e-02, 5.66623035e-02, 6.41218383e-02,
#           8.31475066e+00],
#          [5.88961638e-02, 4.18961485e-02, 4.20776848e-02, 4.95858638e-02,
#           8.61394435e+00],
#          [4.86914802e-02, 4.68340957e-02, 3.79667335e-02, 4.36486849e-02,
#           1.17013310e+01],
#          [3.75547313e-02, 3.88438347e-02, 3.12581395e-02, 3.30878324e-02,
#           1.00547291e+01],
#          [3.40135955e-02, 3.02946707e-02, 3.51884964e-02, 2.86824764e-02,
#           9.36758260e+00],
#          [3.33911956e-02, 2.47868249e-02, 3.17024092e-02, 3.51708262e-02,
#           1.07778303e+01],
#          [2.50885431e-02, 3.21117460e-02, 3.10921206e-02, 2.29154339e-02,
#           1.04718960e+01],
#          [2.55759476e-02, 2.62580719e-02, 2.59381013e-02, 2.26469382e-02,
#           9.74971436e+00],
#          [2.20809606e-02, 1.89635763e-02, 1.84265095e-02, 2.17249076e-02,
#           1.11479471e+01],
#          [1.95782643e-02, 2.03666530e-02, 1.39129892e-02, 1.82039364e-02,
#           8.34252836e+00],
#          [1.36899612e-02, 1.54069619e-02, 1.48239616e-02, 1.85718122e-02,
#           9.50559702e+00],
#          [1.07115945e-02, 1.05202626e-02, 1.48851944e-02, 1.55053234e-02,
#           8.63077827e+00],
#          [1.41160435e-02, 1.24282360e-02, 1.31143801e-02, 1.00245198e-02,
#           8.04859957e+00],
#          [1.04173626e-02, 1.07445711e-02, 9.08053053e-03, 1.17372948e-02,
#           9.66286330e+00],
#          [8.40635751e-03, 1.01655130e-02, 8.30767294e-03, 1.06848596e-02,
#           9.51664680e+00],
#          [7.61285402e-03, 6.37097054e-03, 7.44952247e-03, 7.00320544e-03,
#           8.43574332e+00],
#          [5.77579567e-03, 5.91561690e-03, 6.40921446e-03, 5.96585041e-03,
#           9.23029541e+00],
#          [6.28334933e-03, 6.79240247e-03, 5.18829979e-03, 6.42844110e-03,
#           8.46222353e+00],
#          [4.64548072e-03, 4.47137706e-03, 4.42687575e-03, 5.40248914e-03,
#           1.09536811e+01],
#          [4.95556584e-03, 4.85132392e-03, 4.02904356e-03, 4.24138794e-03,
#           1.02612545e+01],
#          [3.76303981e-03, 3.51864632e-03, 3.53137053e-03, 4.20386049e-03,
#           1.00132448e+01],
#          [3.46674505e-03, 3.39544321e-03, 2.78327101e-03, 3.22738696e-03,
#           1.15465866e+01],
#          [3.64117822e-03, 2.74042772e-03, 2.61029646e-03, 2.97359894e-03,
#           8.85005239e+00],
#          [2.34139351e-03, 2.61153576e-03, 2.07221219e-03, 2.09035246e-03,
#           1.06756577e+01],
#          [2.23475189e-03, 2.43146242e-03, 2.25701157e-03, 2.78368604e-03,
#           8.23879108e+00],
#          [1.78841358e-03, 2.25612881e-03, 1.87736669e-03, 1.64626689e-03,
#           8.18561291e+00],
#          [1.84757118e-03, 1.56239267e-03, 1.62733691e-03, 1.77872980e-03,
#           1.06443941e+01],
#          [1.29924282e-03, 1.59558827e-03, 1.62196161e-03, 1.71471838e-03,
#           9.13026944e+00],
#          [1.27140453e-03, 1.28789349e-03, 1.25049626e-03, 1.25607586e-03,
#           1.08955516e+01]]),
#   array([[8.51678036e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#           0.00000000e+00],
#          [7.61303021e+00, 1.81005756e+00, 3.52075303e-01, 8.37075579e-02,
#           3.15814521e-02],
#          [5.38910939e+00, 2.35260007e+00, 8.49514531e-01, 3.69980464e-01,
#           3.06653894e-01],
#          [3.53071936e+00, 2.00169360e+00, 1.17378690e+00, 8.68272208e-01,
#           9.88267376e-01],
#          [3.07306943e+00, 2.27302181e+00, 1.36486858e+00, 8.81426831e-01,
#           1.69128357e+00],
#          [2.90997538e+00, 1.65727651e+00, 1.43374486e+00, 1.05886613e+00,
#           2.80729400e+00],
#          [2.21348241e+00, 1.58784304e+00, 1.23041023e+00, 1.01995933e+00,
#           5.03545291e+00],
#          [1.56750857e+00, 1.13860530e+00, 8.76931269e-01, 1.04437228e+00,
#           5.36343076e+00],
#          [9.92643738e-01, 9.07052903e-01, 8.10704898e-01, 8.92309880e-01,
#           7.13967029e+00],
#          [1.00759058e+00, 8.65721716e-01, 7.69303033e-01, 7.08649052e-01,
#           6.17415439e+00],
#          [6.65970364e-01, 5.48694438e-01, 4.92908946e-01, 6.25431432e-01,
#           6.92235293e+00],
#          [4.84529085e-01, 4.64491047e-01, 3.66217511e-01, 4.53273883e-01,
#           9.55868463e+00],
#          [4.53915905e-01, 3.82501127e-01, 3.15034167e-01, 3.12927632e-01,
#           1.01886109e+01],
#          [3.37034034e-01, 3.13565702e-01, 2.99894669e-01, 3.00880619e-01,
#           8.61818547e+00],
#          [2.32621212e-01, 2.06000561e-01, 2.47536546e-01, 2.36385778e-01,
#           8.06390071e+00],
#          [1.69922529e-01, 1.32286227e-01, 1.74851213e-01, 1.35995723e-01,
#           1.02687471e+01],
#          [1.22357957e-01, 1.45094749e-01, 1.44170151e-01, 1.38129325e-01,
#           1.13370032e+01],
#          [9.56497031e-02, 8.85109431e-02, 1.00658878e-01, 9.94221753e-02,
#           1.02332799e+01],
#          [8.13608831e-02, 8.66687318e-02, 6.61075884e-02, 7.32818186e-02,
#           1.00472245e+01],
#          [6.19486464e-02, 5.38148514e-02, 6.59674189e-02, 4.85214816e-02,
#           8.21000621e+00],
#          [4.20128929e-02, 4.10438620e-02, 3.76458360e-02, 4.58740075e-02,
#           8.49129750e+00],
#          [3.44392831e-02, 3.08323760e-02, 3.23821032e-02, 2.76640113e-02,
#           8.36772217e+00],
#          [2.90147041e-02, 2.34397698e-02, 2.18650570e-02, 2.18761090e-02,
#           8.91361010e+00],
#          [1.74582488e-02, 1.61415427e-02, 1.69768975e-02, 1.55101568e-02,
#           7.98008059e+00],
#          [1.44691054e-02, 1.62411711e-02, 1.66982972e-02, 1.34147596e-02,
#           8.86117606e+00],
#          [1.23270703e-02, 9.56379704e-03, 1.30393963e-02, 9.68576701e-03,
#           1.11526176e+01],
#          [7.54705268e-03, 7.30732810e-03, 9.09321795e-03, 9.81467018e-03,
#           9.95159249e+00],
#          [6.40247314e-03, 6.94127534e-03, 7.54604485e-03, 7.33745230e-03,
#           1.04186272e+01],
#          [5.48924758e-03, 4.10779022e-03, 5.22855790e-03, 4.51629690e-03,
#           9.63738052e+00],
#          [4.26396345e-03, 3.13703378e-03, 3.13658846e-03, 3.75897541e-03,
#           8.01184193e+00],
#          [3.15464590e-03, 2.48581484e-03, 3.22191300e-03, 3.01535315e-03,
#           1.07590265e+01],
#          [1.83236168e-03, 2.04415087e-03, 2.07779559e-03, 2.23686317e-03,
#           8.98297864e+00],
#          [1.35452172e-03, 1.70887651e-03, 1.58866869e-03, 1.34485369e-03,
#           9.54731985e+00],
#          [1.23871336e-03, 1.10631018e-03, 1.09642492e-03, 1.18829835e-03,
#           1.15266327e+01]])),
#  (array([[8.51678036e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#           0.00000000e+00],
#          [8.28286758e+00, 1.21277213e+00, 2.60522199e-01, 3.87223027e-02,
#           7.03598959e-03],
#          [7.61303021e+00, 1.81005756e+00, 3.52075303e-01, 8.37075579e-02,
#           3.15814521e-02],
#          [7.60029359e+00, 2.53934763e+00, 1.00050901e+00, 3.01052446e-01,
#           2.08922107e-01],
#          [5.38910939e+00, 2.35260007e+00, 8.49514531e-01, 3.69980464e-01,
#           3.06653894e-01],
#          [4.56449516e+00, 2.01172053e+00, 1.32967397e+00, 6.53568960e-01,
#           5.78270309e-01],
#          [3.53071936e+00, 2.00169360e+00, 1.17378690e+00, 8.68272208e-01,
#           9.88267376e-01],
#          [4.40101417e+00, 2.31026849e+00, 1.75426175e+00, 8.45330383e-01,
#           1.56057274e+00],
#          [3.07306943e+00, 2.27302181e+00, 1.36486858e+00, 8.81426831e-01,
#           1.69128357e+00],
#          [2.94982466e+00, 1.74039878e+00, 1.54935687e+00, 1.09908406e+00,
#           2.53792931e+00],
#          [2.90997538e+00, 1.65727651e+00, 1.43374486e+00, 1.05886613e+00,
#           2.80729400e+00],
#          [2.52774387e+00, 1.68323383e+00, 1.45689916e+00, 8.67941004e-01,
#           4.21028965e+00],
#          [2.21348241e+00, 1.58784304e+00, 1.23041023e+00, 1.01995933e+00,
#           5.03545291e+00],
#          [1.88436560e+00, 1.41775301e+00, 1.32178947e+00, 1.09165359e+00,
#           4.65395456e+00],
#          [1.56750857e+00, 1.13860530e+00, 8.76931269e-01, 1.04437228e+00,
#           5.36343076e+00],
#          [1.39013530e+00, 8.67187266e-01, 8.07416573e-01, 9.31501697e-01,
#           6.93539464e+00],
#          [9.92643738e-01, 9.07052903e-01, 8.10704898e-01, 8.92309880e-01,
#           7.13967029e+00],
#          [9.54094570e-01, 7.04054125e-01, 8.11931446e-01, 6.04317636e-01,
#           7.77139295e+00],
#          [1.00759058e+00, 8.65721716e-01, 7.69303033e-01, 7.08649052e-01,
#           6.17415439e+00],
#          [7.23451373e-01, 6.46316770e-01, 6.22587122e-01, 6.09046999e-01,
#           8.23291578e+00],
#          [6.65970364e-01, 5.48694438e-01, 4.92908946e-01, 6.25431432e-01,
#           6.92235293e+00],
#          [4.68324176e-01, 4.68416334e-01, 5.24484854e-01, 4.31285992e-01,
#           8.80400287e+00],
#          [4.84529085e-01, 4.64491047e-01, 3.66217511e-01, 4.53273883e-01,
#           9.55868463e+00],
#          [3.86486388e-01, 3.46606296e-01, 4.40065360e-01, 3.36602873e-01,
#           9.42591316e+00],
#          [4.53915905e-01, 3.82501127e-01, 3.15034167e-01, 3.12927632e-01,
#           1.01886109e+01],
#          [3.24146290e-01, 2.78879581e-01, 3.02855216e-01, 2.67707222e-01,
#           8.47746960e+00],
#          [3.37034034e-01, 3.13565702e-01, 2.99894669e-01, 3.00880619e-01,
#           8.61818547e+00],
#          [2.53870985e-01, 2.14917172e-01, 1.97012445e-01, 1.90597648e-01,
#           9.44831686e+00],
#          [2.32621212e-01, 2.06000561e-01, 2.47536546e-01, 2.36385778e-01,
#           8.06390071e+00],
#          [2.08222821e-01, 1.44498486e-01, 1.99124883e-01, 1.89523744e-01,
#           8.20376469e+00],
#          [1.69922529e-01, 1.32286227e-01, 1.74851213e-01, 1.35995723e-01,
#           1.02687471e+01],
#          [1.29426285e-01, 1.22502740e-01, 1.22182388e-01, 1.51320165e-01,
#           8.80866879e+00],
#          [1.22357957e-01, 1.45094749e-01, 1.44170151e-01, 1.38129325e-01,
#           1.13370032e+01],
#          [1.11395345e-01, 1.20500154e-01, 1.23133396e-01, 9.08308881e-02,
#           9.29572614e+00],
#          [9.56497031e-02, 8.85109431e-02, 1.00658878e-01, 9.94221753e-02,
#           1.02332799e+01],
#          [6.64073428e-02, 7.64403165e-02, 7.62690666e-02, 8.09490757e-02,
#           9.85694810e+00],
#          [8.13608831e-02, 8.66687318e-02, 6.61075884e-02, 7.32818186e-02,
#           1.00472245e+01],
#          [5.03753632e-02, 7.25572526e-02, 5.66623035e-02, 6.41218383e-02,
#           8.31475066e+00],
#          [6.19486464e-02, 5.38148514e-02, 6.59674189e-02, 4.85214816e-02,
#           8.21000621e+00],
#          [4.86914802e-02, 4.68340957e-02, 3.79667335e-02, 4.36486849e-02,
#           1.17013310e+01],
#          [4.20128929e-02, 4.10438620e-02, 3.76458360e-02, 4.58740075e-02,
#           8.49129750e+00],
#          [3.40135955e-02, 3.02946707e-02, 3.51884964e-02, 2.86824764e-02,
#           9.36758260e+00],
#          [3.44392831e-02, 3.08323760e-02, 3.23821032e-02, 2.76640113e-02,
#           8.36772217e+00],
#          [2.50885431e-02, 3.21117460e-02, 3.10921206e-02, 2.29154339e-02,
#           1.04718960e+01],
#          [2.90147041e-02, 2.34397698e-02, 2.18650570e-02, 2.18761090e-02,
#           8.91361010e+00],
#          [2.20809606e-02, 1.89635763e-02, 1.84265095e-02, 2.17249076e-02,
#           1.11479471e+01],
#          [1.74582488e-02, 1.61415427e-02, 1.69768975e-02, 1.55101568e-02,
#           7.98008059e+00],
#          [1.36899612e-02, 1.54069619e-02, 1.48239616e-02, 1.85718122e-02,
#           9.50559702e+00],
#          [1.44691054e-02, 1.62411711e-02, 1.66982972e-02, 1.34147596e-02,
#           8.86117606e+00],
#          [1.41160435e-02, 1.24282360e-02, 1.31143801e-02, 1.00245198e-02,
#           8.04859957e+00],
#          [1.23270703e-02, 9.56379704e-03, 1.30393963e-02, 9.68576701e-03,
#           1.11526176e+01],
#          [8.40635751e-03, 1.01655130e-02, 8.30767294e-03, 1.06848596e-02,
#           9.51664680e+00],
#          [7.54705268e-03, 7.30732810e-03, 9.09321795e-03, 9.81467018e-03,
#           9.95159249e+00],
#          [5.77579567e-03, 5.91561690e-03, 6.40921446e-03, 5.96585041e-03,
#           9.23029541e+00],
#          [6.40247314e-03, 6.94127534e-03, 7.54604485e-03, 7.33745230e-03,
#           1.04186272e+01],
#          [4.64548072e-03, 4.47137706e-03, 4.42687575e-03, 5.40248914e-03,
#           1.09536811e+01],
#          [5.48924758e-03, 4.10779022e-03, 5.22855790e-03, 4.51629690e-03,
#           9.63738052e+00],
#          [3.76303981e-03, 3.51864632e-03, 3.53137053e-03, 4.20386049e-03,
#           1.00132448e+01],
#          [4.26396345e-03, 3.13703378e-03, 3.13658846e-03, 3.75897541e-03,
#           8.01184193e+00],
#          [3.64117822e-03, 2.74042772e-03, 2.61029646e-03, 2.97359894e-03,
#           8.85005239e+00],
#          [3.15464590e-03, 2.48581484e-03, 3.22191300e-03, 3.01535315e-03,
#           1.07590265e+01],
#          [2.23475189e-03, 2.43146242e-03, 2.25701157e-03, 2.78368604e-03,
#           8.23879108e+00],
#          [1.83236168e-03, 2.04415087e-03, 2.07779559e-03, 2.23686317e-03,
#           8.98297864e+00],
#          [1.84757118e-03, 1.56239267e-03, 1.62733691e-03, 1.77872980e-03,
#           1.06443941e+01],
#          [1.35452172e-03, 1.70887651e-03, 1.58866869e-03, 1.34485369e-03,
#           9.54731985e+00],
#          [1.27140453e-03, 1.28789349e-03, 1.25049626e-03, 1.25607586e-03,
#           1.08955516e+01],
#          [1.23871336e-03, 1.10631018e-03, 1.09642492e-03, 1.18829835e-03,
#           1.15266327e+01]]),
#   array([[7.45391115e+00, 7.61656564e-01, 7.37219347e-02, 6.60778277e-03,
#           4.82334671e-04],
#          [6.31537918e+00, 2.25440468e+00, 6.99869349e-01, 1.59682183e-01,
#           8.52162442e-02],
#          [5.41140224e+00, 2.98080193e+00, 1.20718732e+00, 6.36913521e-01,
#           4.75265940e-01],
#          [3.27222225e+00, 2.26336096e+00, 1.41342726e+00, 8.08617233e-01,
#           1.19246083e+00],
#          [3.12149948e+00, 1.96647005e+00, 1.66763659e+00, 9.53115806e-01,
#           2.03565210e+00],
#          [2.29400209e+00, 1.52326497e+00, 1.14354984e+00, 8.92313164e-01,
#           3.98814301e+00],
#          [1.89988352e+00, 1.56306037e+00, 1.16299395e+00, 8.45285916e-01,
#           4.54142844e+00],
#          [1.32814906e+00, 1.14568460e+00, 1.10394608e+00, 7.52703863e-01,
#           6.60503076e+00],
#          [1.23273582e+00, 7.57248110e-01, 9.51023224e-01, 6.19913546e-01,
#           7.21706425e+00],
#          [8.46736355e-01, 5.80723287e-01, 7.19427285e-01, 5.62328022e-01,
#           6.52281615e+00],
#          [6.39641075e-01, 6.16144366e-01, 6.12399719e-01, 4.33389295e-01,
#           8.10399358e+00],
#          [4.41501520e-01, 4.60114954e-01, 4.18473049e-01, 4.06307836e-01,
#           8.57418445e+00],
#          [2.82543470e-01, 3.56376226e-01, 3.00372788e-01, 2.60825441e-01,
#           9.39974289e+00],
#          [3.00365686e-01, 2.64745098e-01, 2.80437013e-01, 2.34341241e-01,
#           7.90221935e+00],
#          [1.62243658e-01, 2.02509147e-01, 1.76624896e-01, 1.75018506e-01,
#           8.39192016e+00],
#          [1.44965201e-01, 1.22884927e-01, 1.29407582e-01, 1.53018715e-01,
#           1.09660503e+01],
#          [1.01594352e-01, 1.05463754e-01, 1.08107256e-01, 1.03961259e-01,
#           1.12009653e+01],
#          [8.32562710e-02, 7.41587181e-02, 9.03583743e-02, 8.62611523e-02,
#           9.43979194e+00],
#          [5.59332641e-02, 6.21132981e-02, 7.11699375e-02, 7.37574496e-02,
#           1.16703506e+01],
#          [5.88961638e-02, 4.18961485e-02, 4.20776848e-02, 4.95858638e-02,
#           8.61394435e+00],
#          [3.75547313e-02, 3.88438347e-02, 3.12581395e-02, 3.30878324e-02,
#           1.00547291e+01],
#          [3.33911956e-02, 2.47868249e-02, 3.17024092e-02, 3.51708262e-02,
#           1.07778303e+01],
#          [2.55759476e-02, 2.62580719e-02, 2.59381013e-02, 2.26469382e-02,
#           9.74971436e+00],
#          [1.95782643e-02, 2.03666530e-02, 1.39129892e-02, 1.82039364e-02,
#           8.34252836e+00],
#          [1.07115945e-02, 1.05202626e-02, 1.48851944e-02, 1.55053234e-02,
#           8.63077827e+00],
#          [1.04173626e-02, 1.07445711e-02, 9.08053053e-03, 1.17372948e-02,
#           9.66286330e+00],
#          [7.61285402e-03, 6.37097054e-03, 7.44952247e-03, 7.00320544e-03,
#           8.43574332e+00],
#          [6.28334933e-03, 6.79240247e-03, 5.18829979e-03, 6.42844110e-03,
#           8.46222353e+00],
#          [4.95556584e-03, 4.85132392e-03, 4.02904356e-03, 4.24138794e-03,
#           1.02612545e+01],
#          [3.46674505e-03, 3.39544321e-03, 2.78327101e-03, 3.22738696e-03,
#           1.15465866e+01],
#          [2.34139351e-03, 2.61153576e-03, 2.07221219e-03, 2.09035246e-03,
#           1.06756577e+01],
#          [1.78841358e-03, 2.25612881e-03, 1.87736669e-03, 1.64626689e-03,
#           8.18561291e+00],
#          [1.29924282e-03, 1.59558827e-03, 1.62196161e-03, 1.71471838e-03,
#           9.13026944e+00]])),
#  (array([[8.51678036e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#           0.00000000e+00],
#          [7.45391115e+00, 7.61656564e-01, 7.37219347e-02, 6.60778277e-03,
#           4.82334671e-04],
#          [7.61303021e+00, 1.81005756e+00, 3.52075303e-01, 8.37075579e-02,
#           3.15814521e-02],
#          [6.31537918e+00, 2.25440468e+00, 6.99869349e-01, 1.59682183e-01,
#           8.52162442e-02],
#          [5.38910939e+00, 2.35260007e+00, 8.49514531e-01, 3.69980464e-01,
#           3.06653894e-01],
#          [5.41140224e+00, 2.98080193e+00, 1.20718732e+00, 6.36913521e-01,
#           4.75265940e-01],
#          [3.53071936e+00, 2.00169360e+00, 1.17378690e+00, 8.68272208e-01,
#           9.88267376e-01],
#          [3.27222225e+00, 2.26336096e+00, 1.41342726e+00, 8.08617233e-01,
#           1.19246083e+00],
#          [3.07306943e+00, 2.27302181e+00, 1.36486858e+00, 8.81426831e-01,
#           1.69128357e+00],
#          [3.12149948e+00, 1.96647005e+00, 1.66763659e+00, 9.53115806e-01,
#           2.03565210e+00],
#          [2.90997538e+00, 1.65727651e+00, 1.43374486e+00, 1.05886613e+00,
#           2.80729400e+00],
#          [2.29400209e+00, 1.52326497e+00, 1.14354984e+00, 8.92313164e-01,
#           3.98814301e+00],
#          [2.21348241e+00, 1.58784304e+00, 1.23041023e+00, 1.01995933e+00,
#           5.03545291e+00],
#          [1.89988352e+00, 1.56306037e+00, 1.16299395e+00, 8.45285916e-01,
#           4.54142844e+00],
#          [1.56750857e+00, 1.13860530e+00, 8.76931269e-01, 1.04437228e+00,
#           5.36343076e+00],
#          [1.32814906e+00, 1.14568460e+00, 1.10394608e+00, 7.52703863e-01,
#           6.60503076e+00],
#          [9.92643738e-01, 9.07052903e-01, 8.10704898e-01, 8.92309880e-01,
#           7.13967029e+00],
#          [1.23273582e+00, 7.57248110e-01, 9.51023224e-01, 6.19913546e-01,
#           7.21706425e+00],
#          [1.00759058e+00, 8.65721716e-01, 7.69303033e-01, 7.08649052e-01,
#           6.17415439e+00],
#          [8.46736355e-01, 5.80723287e-01, 7.19427285e-01, 5.62328022e-01,
#           6.52281615e+00],
#          [6.65970364e-01, 5.48694438e-01, 4.92908946e-01, 6.25431432e-01,
#           6.92235293e+00],
#          [6.39641075e-01, 6.16144366e-01, 6.12399719e-01, 4.33389295e-01,
#           8.10399358e+00],
#          [4.84529085e-01, 4.64491047e-01, 3.66217511e-01, 4.53273883e-01,
#           9.55868463e+00],
#          [4.41501520e-01, 4.60114954e-01, 4.18473049e-01, 4.06307836e-01,
#           8.57418445e+00],
#          [4.53915905e-01, 3.82501127e-01, 3.15034167e-01, 3.12927632e-01,
#           1.01886109e+01],
#          [2.82543470e-01, 3.56376226e-01, 3.00372788e-01, 2.60825441e-01,
#           9.39974289e+00],
#          [3.37034034e-01, 3.13565702e-01, 2.99894669e-01, 3.00880619e-01,
#           8.61818547e+00],
#          [3.00365686e-01, 2.64745098e-01, 2.80437013e-01, 2.34341241e-01,
#           7.90221935e+00],
#          [2.32621212e-01, 2.06000561e-01, 2.47536546e-01, 2.36385778e-01,
#           8.06390071e+00],
#          [1.62243658e-01, 2.02509147e-01, 1.76624896e-01, 1.75018506e-01,
#           8.39192016e+00],
#          [1.69922529e-01, 1.32286227e-01, 1.74851213e-01, 1.35995723e-01,
#           1.02687471e+01],
#          [1.44965201e-01, 1.22884927e-01, 1.29407582e-01, 1.53018715e-01,
#           1.09660503e+01],
#          [1.22357957e-01, 1.45094749e-01, 1.44170151e-01, 1.38129325e-01,
#           1.13370032e+01],
#          [1.01594352e-01, 1.05463754e-01, 1.08107256e-01, 1.03961259e-01,
#           1.12009653e+01],
#          [9.56497031e-02, 8.85109431e-02, 1.00658878e-01, 9.94221753e-02,
#           1.02332799e+01],
#          [8.32562710e-02, 7.41587181e-02, 9.03583743e-02, 8.62611523e-02,
#           9.43979194e+00],
#          [8.13608831e-02, 8.66687318e-02, 6.61075884e-02, 7.32818186e-02,
#           1.00472245e+01],
#          [5.59332641e-02, 6.21132981e-02, 7.11699375e-02, 7.37574496e-02,
#           1.16703506e+01],
#          [6.19486464e-02, 5.38148514e-02, 6.59674189e-02, 4.85214816e-02,
#           8.21000621e+00],
#          [5.88961638e-02, 4.18961485e-02, 4.20776848e-02, 4.95858638e-02,
#           8.61394435e+00],
#          [4.20128929e-02, 4.10438620e-02, 3.76458360e-02, 4.58740075e-02,
#           8.49129750e+00],
#          [3.75547313e-02, 3.88438347e-02, 3.12581395e-02, 3.30878324e-02,
#           1.00547291e+01],
#          [3.44392831e-02, 3.08323760e-02, 3.23821032e-02, 2.76640113e-02,
#           8.36772217e+00],
#          [3.33911956e-02, 2.47868249e-02, 3.17024092e-02, 3.51708262e-02,
#           1.07778303e+01],
#          [2.90147041e-02, 2.34397698e-02, 2.18650570e-02, 2.18761090e-02,
#           8.91361010e+00],
#          [2.55759476e-02, 2.62580719e-02, 2.59381013e-02, 2.26469382e-02,
#           9.74971436e+00],
#          [1.74582488e-02, 1.61415427e-02, 1.69768975e-02, 1.55101568e-02,
#           7.98008059e+00],
#          [1.95782643e-02, 2.03666530e-02, 1.39129892e-02, 1.82039364e-02,
#           8.34252836e+00],
#          [1.44691054e-02, 1.62411711e-02, 1.66982972e-02, 1.34147596e-02,
#           8.86117606e+00],
#          [1.07115945e-02, 1.05202626e-02, 1.48851944e-02, 1.55053234e-02,
#           8.63077827e+00],
#          [1.23270703e-02, 9.56379704e-03, 1.30393963e-02, 9.68576701e-03,
#           1.11526176e+01],
#          [1.04173626e-02, 1.07445711e-02, 9.08053053e-03, 1.17372948e-02,
#           9.66286330e+00],
#          [7.54705268e-03, 7.30732810e-03, 9.09321795e-03, 9.81467018e-03,
#           9.95159249e+00],
#          [7.61285402e-03, 6.37097054e-03, 7.44952247e-03, 7.00320544e-03,
#           8.43574332e+00],
#          [6.40247314e-03, 6.94127534e-03, 7.54604485e-03, 7.33745230e-03,
#           1.04186272e+01],
#          [6.28334933e-03, 6.79240247e-03, 5.18829979e-03, 6.42844110e-03,
#           8.46222353e+00],
#          [5.48924758e-03, 4.10779022e-03, 5.22855790e-03, 4.51629690e-03,
#           9.63738052e+00],
#          [4.95556584e-03, 4.85132392e-03, 4.02904356e-03, 4.24138794e-03,
#           1.02612545e+01],
#          [4.26396345e-03, 3.13703378e-03, 3.13658846e-03, 3.75897541e-03,
#           8.01184193e+00],
#          [3.46674505e-03, 3.39544321e-03, 2.78327101e-03, 3.22738696e-03,
#           1.15465866e+01],
#          [3.15464590e-03, 2.48581484e-03, 3.22191300e-03, 3.01535315e-03,
#           1.07590265e+01],
#          [2.34139351e-03, 2.61153576e-03, 2.07221219e-03, 2.09035246e-03,
#           1.06756577e+01],
#          [1.83236168e-03, 2.04415087e-03, 2.07779559e-03, 2.23686317e-03,
#           8.98297864e+00],
#          [1.78841358e-03, 2.25612881e-03, 1.87736669e-03, 1.64626689e-03,
#           8.18561291e+00],
#          [1.35452172e-03, 1.70887651e-03, 1.58866869e-03, 1.34485369e-03,
#           9.54731985e+00],
#          [1.29924282e-03, 1.59558827e-03, 1.62196161e-03, 1.71471838e-03,
#           9.13026944e+00],
#          [1.23871336e-03, 1.10631018e-03, 1.09642492e-03, 1.18829835e-03,
#           1.15266327e+01]]),
#   array([[8.28286758e+00, 1.21277213e+00, 2.60522199e-01, 3.87223027e-02,
#           7.03598959e-03],
#          [7.60029359e+00, 2.53934763e+00, 1.00050901e+00, 3.01052446e-01,
#           2.08922107e-01],
#          [4.56449516e+00, 2.01172053e+00, 1.32967397e+00, 6.53568960e-01,
#           5.78270309e-01],
#          [4.40101417e+00, 2.31026849e+00, 1.75426175e+00, 8.45330383e-01,
#           1.56057274e+00],
#          [2.94982466e+00, 1.74039878e+00, 1.54935687e+00, 1.09908406e+00,
#           2.53792931e+00],
#          [2.52774387e+00, 1.68323383e+00, 1.45689916e+00, 8.67941004e-01,
#           4.21028965e+00],
#          [1.88436560e+00, 1.41775301e+00, 1.32178947e+00, 1.09165359e+00,
#           4.65395456e+00],
#          [1.39013530e+00, 8.67187266e-01, 8.07416573e-01, 9.31501697e-01,
#           6.93539464e+00],
#          [9.54094570e-01, 7.04054125e-01, 8.11931446e-01, 6.04317636e-01,
#           7.77139295e+00],
#          [7.23451373e-01, 6.46316770e-01, 6.22587122e-01, 6.09046999e-01,
#           8.23291578e+00],
#          [4.68324176e-01, 4.68416334e-01, 5.24484854e-01, 4.31285992e-01,
#           8.80400287e+00],
#          [3.86486388e-01, 3.46606296e-01, 4.40065360e-01, 3.36602873e-01,
#           9.42591316e+00],
#          [3.24146290e-01, 2.78879581e-01, 3.02855216e-01, 2.67707222e-01,
#           8.47746960e+00],
#          [2.53870985e-01, 2.14917172e-01, 1.97012445e-01, 1.90597648e-01,
#           9.44831686e+00],
#          [2.08222821e-01, 1.44498486e-01, 1.99124883e-01, 1.89523744e-01,
#           8.20376469e+00],
#          [1.29426285e-01, 1.22502740e-01, 1.22182388e-01, 1.51320165e-01,
#           8.80866879e+00],
#          [1.11395345e-01, 1.20500154e-01, 1.23133396e-01, 9.08308881e-02,
#           9.29572614e+00],
#          [6.64073428e-02, 7.64403165e-02, 7.62690666e-02, 8.09490757e-02,
#           9.85694810e+00],
#          [5.03753632e-02, 7.25572526e-02, 5.66623035e-02, 6.41218383e-02,
#           8.31475066e+00],
#          [4.86914802e-02, 4.68340957e-02, 3.79667335e-02, 4.36486849e-02,
#           1.17013310e+01],
#          [3.40135955e-02, 3.02946707e-02, 3.51884964e-02, 2.86824764e-02,
#           9.36758260e+00],
#          [2.50885431e-02, 3.21117460e-02, 3.10921206e-02, 2.29154339e-02,
#           1.04718960e+01],
#          [2.20809606e-02, 1.89635763e-02, 1.84265095e-02, 2.17249076e-02,
#           1.11479471e+01],
#          [1.36899612e-02, 1.54069619e-02, 1.48239616e-02, 1.85718122e-02,
#           9.50559702e+00],
#          [1.41160435e-02, 1.24282360e-02, 1.31143801e-02, 1.00245198e-02,
#           8.04859957e+00],
#          [8.40635751e-03, 1.01655130e-02, 8.30767294e-03, 1.06848596e-02,
#           9.51664680e+00],
#          [5.77579567e-03, 5.91561690e-03, 6.40921446e-03, 5.96585041e-03,
#           9.23029541e+00],
#          [4.64548072e-03, 4.47137706e-03, 4.42687575e-03, 5.40248914e-03,
#           1.09536811e+01],
#          [3.76303981e-03, 3.51864632e-03, 3.53137053e-03, 4.20386049e-03,
#           1.00132448e+01],
#          [3.64117822e-03, 2.74042772e-03, 2.61029646e-03, 2.97359894e-03,
#           8.85005239e+00],
#          [2.23475189e-03, 2.43146242e-03, 2.25701157e-03, 2.78368604e-03,
#           8.23879108e+00],
#          [1.84757118e-03, 1.56239267e-03, 1.62733691e-03, 1.77872980e-03,
#           1.06443941e+01],
#          [1.27140453e-03, 1.28789349e-03, 1.25049626e-03, 1.25607586e-03,
#           1.08955516e+01]]))]

# %%
trainData
# Out:
# array([[7.45391115e+00, 7.61656564e-01, 7.37219347e-02, 6.60778277e-03,
#         4.82334671e-04],
#        [8.28286758e+00, 1.21277213e+00, 2.60522199e-01, 3.87223027e-02,
#         7.03598959e-03],
#        [6.31537918e+00, 2.25440468e+00, 6.99869349e-01, 1.59682183e-01,
#         8.52162442e-02],
#        [7.60029359e+00, 2.53934763e+00, 1.00050901e+00, 3.01052446e-01,
#         2.08922107e-01],
#        [5.41140224e+00, 2.98080193e+00, 1.20718732e+00, 6.36913521e-01,
#         4.75265940e-01],
#        [4.56449516e+00, 2.01172053e+00, 1.32967397e+00, 6.53568960e-01,
#         5.78270309e-01],
#        [3.27222225e+00, 2.26336096e+00, 1.41342726e+00, 8.08617233e-01,
#         1.19246083e+00],
#        [4.40101417e+00, 2.31026849e+00, 1.75426175e+00, 8.45330383e-01,
#         1.56057274e+00],
#        [3.12149948e+00, 1.96647005e+00, 1.66763659e+00, 9.53115806e-01,
#         2.03565210e+00],
#        [2.94982466e+00, 1.74039878e+00, 1.54935687e+00, 1.09908406e+00,
#         2.53792931e+00],
#        [2.29400209e+00, 1.52326497e+00, 1.14354984e+00, 8.92313164e-01,
#         3.98814301e+00],
#        [2.52774387e+00, 1.68323383e+00, 1.45689916e+00, 8.67941004e-01,
#         4.21028965e+00],
#        [1.89988352e+00, 1.56306037e+00, 1.16299395e+00, 8.45285916e-01,
#         4.54142844e+00],
#        [1.88436560e+00, 1.41775301e+00, 1.32178947e+00, 1.09165359e+00,
#         4.65395456e+00],
#        [1.32814906e+00, 1.14568460e+00, 1.10394608e+00, 7.52703863e-01,
#         6.60503076e+00],
#        [1.39013530e+00, 8.67187266e-01, 8.07416573e-01, 9.31501697e-01,
#         6.93539464e+00],
#        [1.23273582e+00, 7.57248110e-01, 9.51023224e-01, 6.19913546e-01,
#         7.21706425e+00],
#        [9.54094570e-01, 7.04054125e-01, 8.11931446e-01, 6.04317636e-01,
#         7.77139295e+00],
#        [8.46736355e-01, 5.80723287e-01, 7.19427285e-01, 5.62328022e-01,
#         6.52281615e+00],
#        [7.23451373e-01, 6.46316770e-01, 6.22587122e-01, 6.09046999e-01,
#         8.23291578e+00],
#        [6.39641075e-01, 6.16144366e-01, 6.12399719e-01, 4.33389295e-01,
#         8.10399358e+00],
#        [4.68324176e-01, 4.68416334e-01, 5.24484854e-01, 4.31285992e-01,
#         8.80400287e+00],
#        [4.41501520e-01, 4.60114954e-01, 4.18473049e-01, 4.06307836e-01,
#         8.57418445e+00],
#        [3.86486388e-01, 3.46606296e-01, 4.40065360e-01, 3.36602873e-01,
#         9.42591316e+00],
#        [2.82543470e-01, 3.56376226e-01, 3.00372788e-01, 2.60825441e-01,
#         9.39974289e+00],
#        [3.24146290e-01, 2.78879581e-01, 3.02855216e-01, 2.67707222e-01,
#         8.47746960e+00],
#        [3.00365686e-01, 2.64745098e-01, 2.80437013e-01, 2.34341241e-01,
#         7.90221935e+00],
#        [2.53870985e-01, 2.14917172e-01, 1.97012445e-01, 1.90597648e-01,
#         9.44831686e+00],
#        [1.62243658e-01, 2.02509147e-01, 1.76624896e-01, 1.75018506e-01,
#         8.39192016e+00],
#        [2.08222821e-01, 1.44498486e-01, 1.99124883e-01, 1.89523744e-01,
#         8.20376469e+00],
#        [1.44965201e-01, 1.22884927e-01, 1.29407582e-01, 1.53018715e-01,
#         1.09660503e+01],
#        [1.29426285e-01, 1.22502740e-01, 1.22182388e-01, 1.51320165e-01,
#         8.80866879e+00],
#        [1.01594352e-01, 1.05463754e-01, 1.08107256e-01, 1.03961259e-01,
#         1.12009653e+01],
#        [1.11395345e-01, 1.20500154e-01, 1.23133396e-01, 9.08308881e-02,
#         9.29572614e+00],
#        [8.32562710e-02, 7.41587181e-02, 9.03583743e-02, 8.62611523e-02,
#         9.43979194e+00],
#        [6.64073428e-02, 7.64403165e-02, 7.62690666e-02, 8.09490757e-02,
#         9.85694810e+00],
#        [5.59332641e-02, 6.21132981e-02, 7.11699375e-02, 7.37574496e-02,
#         1.16703506e+01],
#        [5.03753632e-02, 7.25572526e-02, 5.66623035e-02, 6.41218383e-02,
#         8.31475066e+00],
#        [5.88961638e-02, 4.18961485e-02, 4.20776848e-02, 4.95858638e-02,
#         8.61394435e+00],
#        [4.86914802e-02, 4.68340957e-02, 3.79667335e-02, 4.36486849e-02,
#         1.17013310e+01],
#        [3.75547313e-02, 3.88438347e-02, 3.12581395e-02, 3.30878324e-02,
#         1.00547291e+01],
#        [3.40135955e-02, 3.02946707e-02, 3.51884964e-02, 2.86824764e-02,
#         9.36758260e+00],
#        [3.33911956e-02, 2.47868249e-02, 3.17024092e-02, 3.51708262e-02,
#         1.07778303e+01],
#        [2.50885431e-02, 3.21117460e-02, 3.10921206e-02, 2.29154339e-02,
#         1.04718960e+01],
#        [2.55759476e-02, 2.62580719e-02, 2.59381013e-02, 2.26469382e-02,
#         9.74971436e+00],
#        [2.20809606e-02, 1.89635763e-02, 1.84265095e-02, 2.17249076e-02,
#         1.11479471e+01],
#        [1.95782643e-02, 2.03666530e-02, 1.39129892e-02, 1.82039364e-02,
#         8.34252836e+00],
#        [1.36899612e-02, 1.54069619e-02, 1.48239616e-02, 1.85718122e-02,
#         9.50559702e+00],
#        [1.07115945e-02, 1.05202626e-02, 1.48851944e-02, 1.55053234e-02,
#         8.63077827e+00],
#        [1.41160435e-02, 1.24282360e-02, 1.31143801e-02, 1.00245198e-02,
#         8.04859957e+00],
#        [1.04173626e-02, 1.07445711e-02, 9.08053053e-03, 1.17372948e-02,
#         9.66286330e+00],
#        [8.40635751e-03, 1.01655130e-02, 8.30767294e-03, 1.06848596e-02,
#         9.51664680e+00],
#        [7.61285402e-03, 6.37097054e-03, 7.44952247e-03, 7.00320544e-03,
#         8.43574332e+00],
#        [5.77579567e-03, 5.91561690e-03, 6.40921446e-03, 5.96585041e-03,
#         9.23029541e+00],
#        [6.28334933e-03, 6.79240247e-03, 5.18829979e-03, 6.42844110e-03,
#         8.46222353e+00],
#        [4.64548072e-03, 4.47137706e-03, 4.42687575e-03, 5.40248914e-03,
#         1.09536811e+01],
#        [4.95556584e-03, 4.85132392e-03, 4.02904356e-03, 4.24138794e-03,
#         1.02612545e+01],
#        [3.76303981e-03, 3.51864632e-03, 3.53137053e-03, 4.20386049e-03,
#         1.00132448e+01],
#        [3.46674505e-03, 3.39544321e-03, 2.78327101e-03, 3.22738696e-03,
#         1.15465866e+01],
#        [3.64117822e-03, 2.74042772e-03, 2.61029646e-03, 2.97359894e-03,
#         8.85005239e+00],
#        [2.34139351e-03, 2.61153576e-03, 2.07221219e-03, 2.09035246e-03,
#         1.06756577e+01],
#        [2.23475189e-03, 2.43146242e-03, 2.25701157e-03, 2.78368604e-03,
#         8.23879108e+00],
#        [1.78841358e-03, 2.25612881e-03, 1.87736669e-03, 1.64626689e-03,
#         8.18561291e+00],
#        [1.84757118e-03, 1.56239267e-03, 1.62733691e-03, 1.77872980e-03,
#         1.06443941e+01],
#        [1.29924282e-03, 1.59558827e-03, 1.62196161e-03, 1.71471838e-03,
#         9.13026944e+00],
#        [1.27140453e-03, 1.28789349e-03, 1.25049626e-03, 1.25607586e-03,
#         1.08955516e+01]])

# %%
testData
# Out:
# array([[8.51678036e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [7.61303021e+00, 1.81005756e+00, 3.52075303e-01, 8.37075579e-02,
#         3.15814521e-02],
#        [5.38910939e+00, 2.35260007e+00, 8.49514531e-01, 3.69980464e-01,
#         3.06653894e-01],
#        [3.53071936e+00, 2.00169360e+00, 1.17378690e+00, 8.68272208e-01,
#         9.88267376e-01],
#        [3.07306943e+00, 2.27302181e+00, 1.36486858e+00, 8.81426831e-01,
#         1.69128357e+00],
#        [2.90997538e+00, 1.65727651e+00, 1.43374486e+00, 1.05886613e+00,
#         2.80729400e+00],
#        [2.21348241e+00, 1.58784304e+00, 1.23041023e+00, 1.01995933e+00,
#         5.03545291e+00],
#        [1.56750857e+00, 1.13860530e+00, 8.76931269e-01, 1.04437228e+00,
#         5.36343076e+00],
#        [9.92643738e-01, 9.07052903e-01, 8.10704898e-01, 8.92309880e-01,
#         7.13967029e+00],
#        [1.00759058e+00, 8.65721716e-01, 7.69303033e-01, 7.08649052e-01,
#         6.17415439e+00],
#        [6.65970364e-01, 5.48694438e-01, 4.92908946e-01, 6.25431432e-01,
#         6.92235293e+00],
#        [4.84529085e-01, 4.64491047e-01, 3.66217511e-01, 4.53273883e-01,
#         9.55868463e+00],
#        [4.53915905e-01, 3.82501127e-01, 3.15034167e-01, 3.12927632e-01,
#         1.01886109e+01],
#        [3.37034034e-01, 3.13565702e-01, 2.99894669e-01, 3.00880619e-01,
#         8.61818547e+00],
#        [2.32621212e-01, 2.06000561e-01, 2.47536546e-01, 2.36385778e-01,
#         8.06390071e+00],
#        [1.69922529e-01, 1.32286227e-01, 1.74851213e-01, 1.35995723e-01,
#         1.02687471e+01],
#        [1.22357957e-01, 1.45094749e-01, 1.44170151e-01, 1.38129325e-01,
#         1.13370032e+01],
#        [9.56497031e-02, 8.85109431e-02, 1.00658878e-01, 9.94221753e-02,
#         1.02332799e+01],
#        [8.13608831e-02, 8.66687318e-02, 6.61075884e-02, 7.32818186e-02,
#         1.00472245e+01],
#        [6.19486464e-02, 5.38148514e-02, 6.59674189e-02, 4.85214816e-02,
#         8.21000621e+00],
#        [4.20128929e-02, 4.10438620e-02, 3.76458360e-02, 4.58740075e-02,
#         8.49129750e+00],
#        [3.44392831e-02, 3.08323760e-02, 3.23821032e-02, 2.76640113e-02,
#         8.36772217e+00],
#        [2.90147041e-02, 2.34397698e-02, 2.18650570e-02, 2.18761090e-02,
#         8.91361010e+00],
#        [1.74582488e-02, 1.61415427e-02, 1.69768975e-02, 1.55101568e-02,
#         7.98008059e+00],
#        [1.44691054e-02, 1.62411711e-02, 1.66982972e-02, 1.34147596e-02,
#         8.86117606e+00],
#        [1.23270703e-02, 9.56379704e-03, 1.30393963e-02, 9.68576701e-03,
#         1.11526176e+01],
#        [7.54705268e-03, 7.30732810e-03, 9.09321795e-03, 9.81467018e-03,
#         9.95159249e+00],
#        [6.40247314e-03, 6.94127534e-03, 7.54604485e-03, 7.33745230e-03,
#         1.04186272e+01],
#        [5.48924758e-03, 4.10779022e-03, 5.22855790e-03, 4.51629690e-03,
#         9.63738052e+00],
#        [4.26396345e-03, 3.13703378e-03, 3.13658846e-03, 3.75897541e-03,
#         8.01184193e+00],
#        [3.15464590e-03, 2.48581484e-03, 3.22191300e-03, 3.01535315e-03,
#         1.07590265e+01],
#        [1.83236168e-03, 2.04415087e-03, 2.07779559e-03, 2.23686317e-03,
#         8.98297864e+00],
#        [1.35452172e-03, 1.70887651e-03, 1.58866869e-03, 1.34485369e-03,
#         9.54731985e+00],
#        [1.23871336e-03, 1.10631018e-03, 1.09642492e-03, 1.18829835e-03,
#         1.15266327e+01]])

# %% [markdown]
# # Evaluating Folds

# %%
def evaluateFold(model, colnames, parametersToFit, fold,
                 **fittingArgs):
    """
    Calculates the R-squared value for the fit of the predicted test data,
    whose parameters are estimated from the training data, with the observed
    tests data.

    Parameters
    ----------
    model: antimony/ExtendedRoadRunner
    colnames: list-str
        names of data columns
    fold: tuple(np.array, np.array)
        train data, test data
    fittingArgs: dict
        optional arguments for ModelFitter

    Returns
    -------
    float: R squared
    ModelFitter
    """
    # Estimate the parameters
    observedTS = NamedTimeseries(colnames=colnames, array=fold[FOLD_TRAINING])
    fitter = ModelFitter(modelSpecification=model,
                                    parametersToFit=parametersToFit,
                                    observedData=observedTS,
                                    **fittingArgs,
                                    )
    fitter.fitModel()
    parameterDct = dict(fitter.params.valuesdict())
    # Obtain the fitted values for the estimated parameters
    if "endTime" in fittingArgs:
        endTime = fittingArgs["endTime"]
    else:
        endTime = END_TIME
    numPoint = int(10*endTime)
    fittedData = runSimulation(simTime=endTime, numPoint=numPoint,
                                parameterDct=parameterDct,
                                roadRunner=model)
    # Find the time indices that correspond to the test data
    testData = fold[FOLD_TEST]
    testTimes = testData[:, 0]
    fittedTimes = fittedData[:, 0]
    indices = findCloseMatchingValues(fittedTimes, testTimes)
    # Calculate residuals for the corresponding times
    indexArr = np.array(indices)
    fittedTestData = fittedData[indexArr, 1:]
    flatFittedTestData = fittedTestData.flatten()
    flatTestData = (testData[:, 1:]).flatten()
    residualsArr = flatTestData - flatFittedTestData
    rsq = 1 - np.var(residualsArr)/np.var(flatTestData)
    #
    return rsq, fitter

# TESTS
model = te.loada(LINEAR_PATHWAY_MODEL)
colnames = list(LINEAR_PATHWAY_DF.columns)
parametersToFit = [
                Parameter("k1", lower=0, value=0, upper=10),
                Parameter("k2", lower=0, value=0, upper=10),
                Parameter("k3", lower=0, value=0, upper=10),
                Parameter("k4", lower=0, value=0, upper=10),
    ]
folds = generateFolds(LINEAR_PATHWAY_ARR, NUM_FOLD)
rsq, fitter = evaluateFold(model, colnames, parametersToFit, folds[0],
                   fitterMethods=["differential_evolution"])
assert(rsq > 0.85)
assert(isinstance(fitter, ModelFitter))

# %% [markdown]
# # Complete Workflow

# %%
def crossValidate(model, observedData, parametersToFit, colnames, numFold,
                  **fitterArgs):
    """
    Performs cross validation on the model.

    Parameters
    ----------
    model: ExtendedRoadrunner
    observedData: NamedTimeseries
    parametersToFit: list-SBstoat.Parameter
    colnames: list-str
    numFold: int

    Results
    -------
    pd.DataFrame
        Index: fold
        Columns
            R2: R squared value
            values of parameters
    """
    folds = generateFolds(observedData, numFold)
    result = {p.name: [] for p in parametersToFit}
    result[RSQ] = []
    for fold in folds:
        foldQuality, fitter = evaluateFold(model, colnames, parametersToFit,
                                           fold, **fitterArgs)
        result[RSQ].append(foldQuality)
        valueDct = fitter.params.valuesdict()
        for parameter in parametersToFit:
            result[parameter.name].append(valueDct[parameter.name])
    df = pd.DataFrame(result)
    return df

# TESTS
model = te.loada(LINEAR_PATHWAY_MODEL)
colnames = list(LINEAR_PATHWAY_DF.columns)
parametersToFit = [
                Parameter("k1", lower=0, value=0, upper=10),
                Parameter("k2", lower=0, value=0, upper=10),
                Parameter("k3", lower=0, value=0, upper=10),
                Parameter("k4", lower=0, value=0, upper=10),
    ]
observedData = NamedTimeseries(dataframe=LINEAR_PATHWAY_DF)
resultDF = crossValidate(model, observedData, parametersToFit,
                          colnames, NUM_FOLD,
                          fitterMethods=["differential_evolution"])
trues = [q > 0.85 for q in resultDF[RSQ]]
assert(all(trues))

# %%
resultDF
# Out:
#          k1        k2        k3        k4                 rsq
# 0  1.067134  2.266263  3.098654  4.675622  0.8616328105257536
# 1  1.012531  2.241224  3.162889  4.218377  0.8819547031789439
# 2  1.021859  2.059663  3.071069  4.111144  0.8867244027452357

# %% [markdown]
# # Exercises

# %% [markdown]
# This exerise uses the ``WOLF_MODEL`` and the data ``WOLF_DF``.
# Only fit the parameters ``J1_k1``, ``J1_ki``, and ``J1_n``.
#
# 1. Do 2, 10, 20, and 100 fold cross validations. Save the fold qualities in a python dictionary.
#
# 1. Some questions about the results in (1).
#    1. How does the mean value of quality change with the number of folds?
#
#    1. Can you explain the trend in the standard deviations of the quality scores?
#
# 1. Plot the distribution of quality scores for 20 and 100 folds.
# What can you say about these distributions?
#    1. Hint: If ``resultDF`` is the DataFrame returned by ``crossvalidate``,
#    then ``list(resultDF[RSQ])`` is the list of $R^2$ values for the folds.

# %% [markdown]
# ## (1) Calculate Cross Validations

# %%
model = te.loada(WOLF_MODEL)
colnames = list(WOLF_DF.columns)
observedData = NamedTimeseries(dataframe=WOLF_DF)

# %%
upper = 1e5
parametersToFit = [
      Parameter("J1_k1", lower=0, value=1, upper=upper), #550
      Parameter("J1_Ki", lower=0, value=1, upper=upper), #1
      Parameter("J1_n", lower=0, value=1, upper=upper), #4                                                                                                                                                                 
]

# %%
resultDct = {}
for numFold in [2, 10, 20, 100]:
    qualityDF = crossValidate(model, observedData, parametersToFit,
                          colnames, numFold,
                          fitterMethods=["differential_evolution"],
                          endTime=5)
    resultDct[numFold] = qualityDF
# Out:
# 9.192157:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.203144:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.213399:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.223716:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.308300:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.318779:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.329160:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.339957:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.504449:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.515773:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.525797:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 9.535712:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 11.439864:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 11.442977:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 11.445268:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 11.447103:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 12.176738:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 15.626281:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 15.637972:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 15.648602:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 15.659098:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 16.263921:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 16.807317:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 17.193547:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 19.559498:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 19.570391:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 19.580717:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 19.591456:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 21.456464:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 21.467887:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 21.478593:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 21.490681:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 23.823946:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 23.835956:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 23.846055:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 23.856679:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 25.248876:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 26.303914:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 26.314868:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 26.325255:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 26.335739:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 26.553912:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 26.565113:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 26.575604:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 26.586078:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 28.540914:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 28.552027:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 28.563417:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 28.573668:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 30.663846:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 30.675702:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 30.685998:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 30.696630:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 31.721437:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 32.802960:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 32.813830:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 32.824908:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 32.835804:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 34.351963:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 34.368090:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 34.380444:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 34.393974:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 36.427565:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 36.438151:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 36.448003:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 36.457893:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 38.463715:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 38.474241:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 38.484520:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 38.494489:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 40.345723:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 40.356960:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 40.368371:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 40.379651:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 40.968991:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 40.979928:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 40.990251:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 41.000614:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 43.617768:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 43.628662:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 43.639325:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 43.649595:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 43.912428:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 43.923481:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 43.933974:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 43.944396:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 46.392064:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 46.402816:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 46.413076:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 46.423733:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 49.033200:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 49.044041:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 49.054274:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 49.064502:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 51.443590:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 51.454824:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 51.465158:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 51.475366:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 51.740323:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 51.922799:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 53.468720:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 53.479471:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 53.489814:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 53.500201:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 56.260266:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 56.270980:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 56.281034:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 56.291164:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 60.968033:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 60.978700:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 60.989205:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 60.999457:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 63.145221:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 63.155610:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 63.165490:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 63.175498:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 64.642664:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 66.723315:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 67.246616:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 67.257113:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 67.267352:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 67.277805:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 67.632169:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 67.642744:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 67.652872:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 67.663043:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 68.892354:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 69.499685:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 69.510992:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 69.521169:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 69.531178:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 73.235157:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 73.246106:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 73.256279:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 73.266819:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 75.612370:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 75.623074:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 75.633293:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 75.643422:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 76.017009:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 77.867480:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 77.878104:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 77.888016:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 77.898017:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 77.954829:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 77.964971:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 77.974785:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 77.990265:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 79.883369:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 79.893867:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 79.904091:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 79.913924:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 82.552123:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 82.562677:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 82.572995:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 82.582941:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 85.285700:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 85.296585:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 85.306783:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 85.317065:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 85.651460:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 87.342369:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 87.354416:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 87.365757:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 87.376109:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 92.054415:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 92.065477:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 92.076207:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 92.086745:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 92.361358:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 93.312792:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 94.166457:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 94.177262:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 94.189026:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 94.201843:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 94.439999:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 94.451563:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 94.462451:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 94.473344:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 96.214653:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 96.232122:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 96.249039:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 96.269109:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# ...
#
# 292.320793:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 292.333000:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 292.343321:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 292.354479:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 292.461687:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 292.473318:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 292.483608:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 292.495617:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 294.698030:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 294.709496:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 294.720098:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 294.730811:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 294.828420:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 294.839407:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 294.850173:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 294.861056:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 295.825609:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 298.405986:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.153496:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.165402:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.175563:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.187402:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.445958:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.457123:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.467798:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.478390:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.903696:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.914778:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.926371:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 299.936905:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 301.851247:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 301.863314:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 301.873582:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 301.884010:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 303.292081:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 304.891734:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 306.019793:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 306.030840:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 306.041533:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 306.052088:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 308.087655:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 308.098710:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 308.109012:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 308.118932:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 310.029008:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 310.040369:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 310.051058:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 310.061574:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 310.987718:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 310.999449:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 311.009995:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 311.020538:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 313.131701:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 313.143424:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 313.153693:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 313.164294:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 314.705502:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 315.050920:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 315.064517:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 315.075275:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))
#
# 315.087622:     (Roadrunner exception: : CVODE Error: CV_CONV_FAILURE: Convergence test failures occurred too many times (= MXNCF = 10) during one internal timestep or occurred with |h| = hmin.; In virtual double rr::CVODEIntegrator::integrate(double, double))

# %% [markdown]
# ## (2) Questions

# %% [markdown]
# 1. The mean values of $R^2$ change little as the folds increase, although there is a small decrease at 100 folds.
# 1. The standard deviation of $R^2$ increases with the number of folds.
# This is because with fewer data values in the test data,
# there is more variability in how well the model fits.

# %% [markdown]
# ## (3) Plot the distributions

# %%
def plotHist(numFold):
    """
    Plots a histogram for the number of folds.

    Parameters
    ----------
    numFold: int
    """
    _ = plt.hist(resultDct[numFold][RSQ])
    plt.xlim([0, 1.0])
    plt.title("Folds: %d" % numFold)

# %%
plotHist(20)

# %%
plotHist(100)

# %% [markdown]
# The histogram plots are consistent with the observation that variance increases with the number of folds.
